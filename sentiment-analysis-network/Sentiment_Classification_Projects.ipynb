# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over 
# all the words in all the reviews and increment 
# the counts in the appropriate counter objects

for i in range(len(reviews)):
    
    if(labels[i] == 'POSITIVE'):
        for word in reviews[i].split(" "):
            positive_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in reviews[i].split(" "):
            negative_counts[word] += 1
            total_counts[word] += 1

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 1651404),
#  ('the', 519972),
#  ('.', 478962),
#  ('and', 269166),
#  ('a', 251064),
#  ('of', 230565),
#  ('to', 200238),
#  ('is', 171735),
#  ('in', 150645),
#  ('br', 147705),
#  ('it', 144075),
#  ('i', 122229),
#  ('that', 106890),
#  ('this', 105240),
#  ('s', 101445),
#  ('as', 78924),
#  ('with', 69741),
#  ('for', 67248),
#  ('was', 65751),
#  ('film', 62811),
#  ('but', 62466),
#  ('movie', 57222),
#  ('his', 51681),
#  ('on', 51024),
#  ('you', 50043),
#  ('he', 48846),
#  ('are', 44421),
#  ('not', 42816),
#  ('t', 41160),
#  ('one', 40965),
#  ('have', 37761),
#  ('be', 37248),
#  ('by', 35991),
#  ('all', 35826),
#  ('who', 34392),
#  ('an', 33882),
#  ('at', 33702),
#  ('from', 32301),
#  ('her', 31422),
#  ('they', 29685),
#  ('has', 27558),
#  ('so', 27462),
#  ('like', 27114),
#  ('about', 24939),
#  ('very', 24915),
#  ('out', 24402),
#  ('there', 24171),
#  ('she', 23337),
#  ('what', 23211),
#  ('or', 23196),
#  ('good', 23160),
#  ('more', 22563),
#  ('when', 22368),
#  ('some', 22323),
#  ('if', 21855),
#  ('just', 21456),
#  ('can', 21003),
#  ('story', 20340),
#  ('time', 19545),
#  ('my', 19464),
#  ('great', 19257),
#  ('well', 19215),
#  ('up', 18963),
#  ('which', 18801),
#  ('their', 18321),
#  ('see', 18078),
#  ('also', 16650),
#  ('we', 16593),
#  ('really', 16428),
#  ('would', 16200),
#  ('will', 15654),
#  ('me', 15501),
#  ('had', 15444),
#  ('only', 15411),
#  ('him', 15054),
#  ('even', 14892),
#  ('most', 14592),
#  ('other', 14574),
#  ('were', 14346),
#  ('first', 14265),
#  ('than', 14208),
#  ('much', 14055),
#  ('its', 13866),
#  ('no', 13722),
#  ('into', 13632),
#  ('people', 13437),
#  ('best', 12957),
#  ('love', 12903),
#  ('get', 12816),
#  ('how', 12639),
#  ('life', 12597),
#  ('been', 12567),
#  ('because', 12237),
#  ('way', 12108),
#  ('do', 11823),
#  ('made', 11469),
#  ('films', 11439),
#  ('them', 11415),
#  ('after', 11400),
#  ('many', 11298),
#  ('two', 11199),
#  ('too', 10977),
#  ('think', 10965),
#  ('movies', 10758),
#  ('characters', 10680),
#  ('character', 10542),
#  ('don', 10404),
#  ('man', 10380),
#  ('show', 10296),
#  ('watch', 10272),
#  ('seen', 10242),
#  ('then', 10074),
#  ('little', 10023),
#  ('still', 10020),
#  ('make', 9909),
#  ('could', 9711),
#  ('never', 9678),
#  ('being', 9651),
#  ('where', 9519),
#  ('does', 9207),
#  ('over', 9051),
#  ('any', 9006),
#  ('while', 8697),
#  ('know', 8499),
#  ('did', 8370),
#  ('years', 8274),
#  ('here', 8220),
#  ('ever', 8202),
#  ('end', 8088),
#  ('these', 8082),
#  ('such', 7770),
#  ('real', 7704),
#  ('scene', 7701),
#  ('back', 7641),
#  ('those', 7455),
#  ('though', 7425),
#  ('off', 7389),
#  ('new', 7374),
#  ('your', 7359),
#  ('go', 7320),
#  ('acting', 7311),
#  ('plot', 7296),
#  ('world', 7287),
#  ('scenes', 7281),
#  ('say', 7242),
#  ('through', 7227),
#  ('makes', 7170),
#  ('better', 7143),
#  ('now', 7104),
#  ('work', 7038),
#  ('young', 7029),
#  ('old', 6933),
#  ('ve', 6921),
#  ('find', 6816),
#  ('both', 6744),
#  ('before', 6531),
#  ('us', 6486),
#  ('again', 6474),
#  ('series', 6459),
#  ('quite', 6429),
#  ('something', 6405),
#  ('cast', 6399),
#  ('should', 6363),
#  ('part', 6294),
#  ('always', 6264),
#  ('lot', 6261),
#  ('another', 6225),
#  ('actors', 6141),
#  ('director', 6120),
#  ('family', 6096),
#  ('between', 6048),
#  ('own', 6048),
#  ('m', 5994),
#  ('may', 5991),
#  ('same', 5916),
#  ('role', 5901),
#  ('watching', 5898),
#  ('every', 5862),
#  ('funny', 5859),
#  ('doesn', 5805),
#  ('performance', 5784),
#  ('few', 5754),
#  ('bad', 5721),
#  ('look', 5700),
#  ('re', 5652),
#  ('why', 5565),
#  ('things', 5547),
#  ('times', 5496),
#  ('big', 5445),
#  ('however', 5385),
#  ('actually', 5370),
#  ('action', 5367),
#  ('going', 5349),
#  ('bit', 5271),
#  ('comedy', 5226),
#  ('down', 5220),
#  ('music', 5214),
#  ('must', 5184),
#  ('take', 5127),
#  ('saw', 5076),
#  ('long', 5070),
#  ('right', 5064),
#  ('fun', 5058),
#  ('fact', 5052),
#  ('excellent', 5049),
#  ('around', 5022),
#  ('didn', 5016),
#  ('without', 5013),
#  ('thing', 4986),
#  ('thought', 4917),
#  ('got', 4905),
#  ('each', 4890),
#  ('day', 4842),
#  ('feel', 4791),
#  ('seems', 4788),
#  ('come', 4782),
#  ('done', 4758),
#  ('beautiful', 4740),
#  ('especially', 4716),
#  ('played', 4713),
#  ('almost', 4698),
#  ('want', 4686),
#  ('yet', 4668),
#  ('give', 4659),
#  ('pretty', 4647),
#  ('last', 4629),
#  ('since', 4557),
#  ('different', 4512),
#  ('although', 4503),
#  ('gets', 4470),
#  ('true', 4461),
#  ('interesting', 4443),
#  ('job', 4410),
#  ('enough', 4365),
#  ('our', 4362),
#  ('shows', 4341),
#  ('horror', 4323),
#  ('woman', 4317),
#  ('tv', 4200),
#  ('probably', 4194),
#  ('father', 4185),
#  ('original', 4179),
#  ('girl', 4170),
#  ('point', 4137),
#  ('plays', 4134),
#  ('wonderful', 4116),
#  ('far', 4074),
#  ('course', 4074),
#  ('john', 4050),
#  ('rather', 4020),
#  ('isn', 3984),
#  ('ll', 3978),
#  ('later', 3972),
#  ('dvd', 3972),
#  ('whole', 3930),
#  ('war', 3930),
#  ('d', 3921),
#  ('found', 3918),
#  ('away', 3918),
#  ('screen', 3915),
#  ('nothing', 3900),
#  ('year', 3891),
#  ('once', 3888),
#  ('hard', 3882),
#  ('together', 3840),
#  ('set', 3831),
#  ('am', 3831),
#  ('having', 3798),
#  ('making', 3795),
#  ('place', 3789),
#  ('might', 3780),
#  ('comes', 3780),
#  ('sure', 3759),
#  ('american', 3744),
#  ('play', 3735),
#  ('kind', 3732),
#  ('perfect', 3726),
#  ('takes', 3726),
#  ('performances', 3711),
#  ('himself', 3690),
#  ('worth', 3663),
#  ('everyone', 3663),
#  ('anyone', 3642),
#  ('actor', 3609),
#  ('three', 3603),
#  ('wife', 3588),
#  ('classic', 3576),
#  ('goes', 3558),
#  ('ending', 3534),
#  ('version', 3504),
#  ('star', 3447),
#  ('enjoy', 3438),
#  ('book', 3426),
#  ('nice', 3396),
#  ('everything', 3384),
#  ('during', 3372),
#  ('put', 3354),
#  ('seeing', 3333),
#  ('least', 3306),
#  ('house', 3300),
#  ('high', 3285),
#  ('watched', 3282),
#  ('loved', 3261),
#  ('men', 3261),
#  ('night', 3246),
#  ('anything', 3225),
#  ('believe', 3213),
#  ('guy', 3213),
#  ('top', 3189),
#  ('amazing', 3174),
#  ('hollywood', 3168),
#  ('looking', 3159),
#  ('main', 3132),
#  ('definitely', 3129),
#  ('gives', 3093),
#  ('home', 3087),
#  ('seem', 3084),
#  ('episode', 3069),
#  ('audience', 3060),
#  ('sense', 3060),
#  ('truly', 3051),
#  ('special', 3033),
#  ('second', 3027),
#  ('short', 3027),
#  ('fan', 3027),
#  ('mind', 3015),
#  ('human', 3003),
#  ('recommend', 2997),
#  ('full', 2988),
#  ('black', 2985),
#  ('help', 2973),
#  ('along', 2967),
#  ('trying', 2961),
#  ('small', 2958),
#  ('death', 2955),
#  ('friends', 2943),
#  ('remember', 2922),
#  ('often', 2910),
#  ('said', 2898),
#  ('favorite', 2886),
#  ('heart', 2877),
#  ('early', 2871),
#  ('left', 2868),
#  ('until', 2865),
#  ('script', 2862),
#  ('let', 2862),
#  ('maybe', 2811),
#  ('today', 2808),
#  ('live', 2802),
#  ('less', 2802),
#  ('moments', 2799),
#  ('others', 2787),
#  ('brilliant', 2778),
#  ('shot', 2775),
#  ('liked', 2769),
#  ('become', 2748),
#  ('won', 2745),
#  ('used', 2730),
#  ('style', 2721),
#  ('mother', 2685),
#  ('lives', 2682),
#  ('came', 2679),
#  ('stars', 2670),
#  ('cinema', 2667),
#  ('looks', 2655),
#  ('perhaps', 2652),
#  ('read', 2646),
#  ('enjoyed', 2637),
#  ('boy', 2625),
#  ('drama', 2619),
#  ('highly', 2613),
#  ('given', 2610),
#  ('playing', 2601),
#  ('use', 2592),
#  ('next', 2577),
#  ('women', 2574),
#  ('fine', 2571),
#  ('effects', 2568),
#  ('kids', 2562),
#  ('entertaining', 2559),
#  ('need', 2556),
#  ('line', 2550),
#  ('works', 2544),
#  ('someone', 2541),
#  ('mr', 2508),
#  ('simply', 2505),
#  ('picture', 2499),
#  ('children', 2499),
#  ('face', 2493),
#  ('keep', 2493),
#  ('friend', 2493),
#  ('dark', 2490),
#  ('overall', 2484),
#  ('certainly', 2484),
#  ('minutes', 2481),
#  ('wasn', 2472),
#  ('history', 2466),
#  ('finally', 2460),
#  ('couple', 2448),
#  ('against', 2445),
#  ('son', 2427),
#  ('understand', 2424),
#  ('lost', 2421),
#  ('michael', 2415),
#  ('else', 2403),
#  ('throughout', 2394),
#  ('fans', 2391),
#  ('city', 2376),
#  ('reason', 2367),
#  ('written', 2361),
#  ('production', 2361),
#  ('several', 2352),
#  ('school', 2349),
#  ('based', 2343),
#  ('rest', 2343),
#  ('try', 2340),
#  ('dead', 2328),
#  ('hope', 2325),
#  ('strong', 2304),
#  ('white', 2295),
#  ('tell', 2277),
#  ('itself', 2274),
#  ('half', 2259),
#  ('person', 2247),
#  ('sometimes', 2238),
#  ('past', 2232),
#  ('start', 2232),
#  ('genre', 2229),
#  ('beginning', 2217),
#  ('final', 2217),
#  ('town', 2214),
#  ('art', 2202),
#  ('humor', 2196),
#  ('game', 2196),
#  ('yes', 2193),
#  ('idea', 2193),
#  ('late', 2190),
#  ('becomes', 2187),
#  ('despite', 2187),
#  ('able', 2178),
#  ('case', 2178),
#  ('money', 2169),
#  ('child', 2163),
#  ('completely', 2163),
#  ('side', 2157),
#  ('camera', 2148),
#  ('getting', 2142),
#  ('instead', 2136),
#  ('soon', 2106),
#  ('under', 2100),
#  ('viewer', 2097),
#  ('age', 2091),
#  ('days', 2088),
#  ('stories', 2088),
#  ('felt', 2082),
#  ('simple', 2082),
#  ('roles', 2079),
#  ('video', 2064),
#  ('name', 2049),
#  ('either', 2049),
#  ('doing', 2031),
#  ('turns', 2022),
#  ('wants', 2013),
#  ('close', 2013),
#  ('title', 2007),
#  ('wrong', 2004),
#  ('went', 1998),
#  ('james', 1995),
#  ('evil', 1977),
#  ('budget', 1971),
#  ('episodes', 1971),
#  ('relationship', 1965),
#  ('fantastic', 1959),
#  ('piece', 1959),
#  ('david', 1953),
#  ('turn', 1944),
#  ('murder', 1938),
#  ('parts', 1935),
#  ('brother', 1932),
#  ('absolutely', 1929),
#  ('head', 1929),
#  ('experience', 1926),
#  ('eyes', 1923),
#  ('sex', 1914),
#  ('direction', 1911),
#  ('called', 1911),
#  ('directed', 1908),
#  ('lines', 1902),
#  ('behind', 1899),
#  ('sort', 1896),
#  ('actress', 1893),
#  ('lead', 1890),
#  ('oscar', 1884),
#  ('including', 1881),
#  ('example', 1881),
#  ('known', 1875),
#  ('musical', 1875),
#  ('chance', 1863),
#  ('score', 1860),
#  ('already', 1857),
#  ('feeling', 1857),
#  ('hit', 1857),
#  ('voice', 1845),
#  ('moment', 1836),
#  ('living', 1836),
#  ('low', 1830),
#  ('supporting', 1830),
#  ('ago', 1827),
#  ('themselves', 1824),
#  ('reality', 1815),
#  ('hilarious', 1815),
#  ('jack', 1812),
#  ('told', 1809),
#  ('hand', 1803),
#  ('quality', 1800),
#  ('moving', 1800),
#  ('dialogue', 1800),
#  ('song', 1797),
#  ('happy', 1797),
#  ('matter', 1794),
#  ('paul', 1794),
#  ('light', 1782),
#  ('future', 1779),
#  ('entire', 1776),
#  ('finds', 1773),
#  ('gave', 1767),
#  ('laugh', 1761),
#  ('released', 1758),
#  ('expect', 1752),
#  ('fight', 1743),
#  ('particularly', 1740),
#  ('cinematography', 1737),
#  ('police', 1737),
#  ('whose', 1734),
#  ('type', 1734),
#  ('sound', 1734),
#  ('view', 1719),
#  ('enjoyable', 1719),
#  ('number', 1716),
#  ('romantic', 1716),
#  ('husband', 1716),
#  ('daughter', 1716),
#  ('documentary', 1713),
#  ('self', 1710),
#  ('superb', 1707),
#  ('modern', 1707),
#  ('took', 1707),
#  ('robert', 1707),
#  ('mean', 1698),
#  ('shown', 1689),
#  ('coming', 1683),
#  ('important', 1680),
#  ('king', 1677),
#  ('leave', 1677),
#  ('change', 1674),
#  ('somewhat', 1665),
#  ('wanted', 1665),
#  ('tells', 1662),
#  ('events', 1656),
#  ('run', 1656),
#  ('career', 1656),
#  ('country', 1656),
#  ('heard', 1650),
#  ('season', 1650),
#  ('greatest', 1647),
#  ('girls', 1647),
#  ('etc', 1641),
#  ('care', 1638),
#  ('starts', 1635),
#  ('english', 1626),
#  ('killer', 1623),
#  ('tale', 1620),
#  ('guys', 1620),
#  ('totally', 1620),
#  ('animation', 1620),
#  ('usual', 1617),
#  ('miss', 1605),
#  ('opinion', 1605),
#  ('easy', 1593),
#  ('violence', 1593),
#  ('songs', 1590),
#  ('british', 1584),
#  ('says', 1578),
#  ('realistic', 1575),
#  ('writing', 1572),
#  ('writer', 1566),
#  ('act', 1566),
#  ('comic', 1563),
#  ('thriller', 1557),
#  ('television', 1551),
#  ('power', 1548),
#  ('ones', 1545),
#  ('kid', 1542),
#  ('york', 1539),
#  ('novel', 1539),
#  ('alone', 1536),
#  ('problem', 1536),
#  ('attention', 1527),
#  ('involved', 1524),
#  ('kill', 1521),
#  ('extremely', 1521),
#  ('seemed', 1518),
#  ('hero', 1515),
#  ('french', 1515),
#  ('rock', 1512),
#  ('stuff', 1503),
#  ('wish', 1497),
#  ('begins', 1494),
#  ('taken', 1491),
#  ('sad', 1491),
#  ('ways', 1488),
#  ('richard', 1485),
#  ('knows', 1482),
#  ('atmosphere', 1479),
#  ('similar', 1473),
#  ('surprised', 1473),
#  ('taking', 1473),
#  ('car', 1473),
#  ('george', 1470),
#  ('perfectly', 1470),
#  ('across', 1467),
#  ('team', 1467),
#  ('eye', 1467),
#  ('sequence', 1467),
#  ('room', 1464),
#  ('due', 1464),
#  ('among', 1464),
#  ('serious', 1464),
#  ('powerful', 1464),
#  ('strange', 1461),
#  ('order', 1461),
#  ('cannot', 1461),
#  ('b', 1461),
#  ('beauty', 1458),
#  ('famous', 1455),
#  ('happened', 1452),
#  ('tries', 1452),
#  ('herself', 1452),
#  ('myself', 1452),
#  ('class', 1449),
#  ('four', 1446),
#  ('cool', 1443),
#  ('release', 1437),
#  ('anyway', 1437),
#  ('theme', 1437),
#  ('opening', 1434),
#  ('entertainment', 1431),
#  ('slow', 1425),
#  ('ends', 1425),
#  ('unique', 1425),
#  ('exactly', 1425),
#  ('easily', 1422),
#  ('level', 1422),
#  ('o', 1422),
#  ('red', 1422),
#  ('interest', 1416),
#  ('happen', 1413),
#  ('crime', 1410),
#  ('viewing', 1404),
#  ('sets', 1401),
#  ('memorable', 1401),
#  ('stop', 1398),
#  ('group', 1398),
#  ('problems', 1389),
#  ('dance', 1389),
#  ('working', 1389),
#  ('sister', 1389),
#  ('message', 1389),
#  ('knew', 1386),
#  ('mystery', 1383),
#  ('nature', 1383),
#  ('bring', 1380),
#  ('believable', 1377),
#  ('thinking', 1377),
#  ('brought', 1377),
#  ('mostly', 1374),
#  ('disney', 1371),
#  ('couldn', 1371),
#  ('society', 1368),
#  ('lady', 1365),
#  ('within', 1365),
#  ('blood', 1362),
#  ('parents', 1359),
#  ('upon', 1359),
#  ('viewers', 1359),
#  ('meets', 1356),
#  ('form', 1356),
#  ('peter', 1356),
#  ('tom', 1356),
#  ('usually', 1356),
#  ('soundtrack', 1356),
#  ('local', 1350),
#  ('certain', 1344),
#  ('follow', 1344),
#  ('whether', 1341),
#  ('possible', 1338),
#  ('emotional', 1335),
#  ('killed', 1332),
#  ('above', 1332),
#  ('de', 1332),
#  ('god', 1329),
#  ('middle', 1329),
#  ('needs', 1326),
#  ('happens', 1326),
#  ('flick', 1326),
#  ('masterpiece', 1323),
#  ('period', 1320),
#  ('major', 1320),
#  ('named', 1317),
#  ('haven', 1317),
#  ('particular', 1314),
#  ('th', 1314),
#  ('earth', 1311),
#  ('feature', 1311),
#  ('stand', 1308),
#  ('words', 1305),
#  ('typical', 1305),
#  ('elements', 1299),
#  ('obviously', 1299),
#  ('romance', 1293),
#  ('jane', 1290),
#  ('yourself', 1281),
#  ('showing', 1281),
#  ('brings', 1278),
#  ('fantasy', 1278),
#  ('guess', 1269),
#  ('america', 1269),
#  ('unfortunately', 1266),
#  ('huge', 1266),
#  ('indeed', 1263),
#  ('running', 1263),
#  ('talent', 1260),
#  ('stage', 1257),
#  ('started', 1254),
#  ('leads', 1251),
#  ('sweet', 1251),
#  ('japanese', 1251),
#  ('poor', 1248),
#  ('deal', 1248),
#  ('incredible', 1239),
#  ('personal', 1239),
#  ('fast', 1236),
#  ('became', 1230),
#  ('deep', 1230),
#  ('hours', 1227),
#  ('giving', 1224),
#  ('nearly', 1224),
#  ('dream', 1224),
#  ('clearly', 1221),
#  ('turned', 1221),
#  ('obvious', 1218),
#  ('near', 1218),
#  ('cut', 1215),
#  ('surprise', 1215),
#  ('era', 1212),
#  ('body', 1212),
#  ('hour', 1209),
#  ('female', 1209),
#  ('five', 1209),
#  ('note', 1197),
#  ('learn', 1194),
#  ('truth', 1194),
#  ('except', 1191),
#  ('feels', 1191),
#  ('match', 1191),
#  ('tony', 1191),
#  ('filmed', 1182),
#  ('clear', 1182),
#  ('complete', 1182),
#  ('street', 1179),
#  ('eventually', 1179),
#  ('keeps', 1179),
#  ('older', 1179),
#  ('lots', 1179),
#  ('buy', 1176),
#  ('william', 1173),
#  ('stewart', 1173),
#  ('fall', 1170),
#  ('joe', 1170),
#  ('meet', 1170),
#  ('unlike', 1167),
#  ('talking', 1167),
#  ('shots', 1167),
#  ('rating', 1167),
#  ('difficult', 1167),
#  ('dramatic', 1164),
#  ('means', 1164),
#  ('situation', 1158),
#  ('wonder', 1158),
#  ('present', 1158),
#  ('appears', 1158),
#  ('subject', 1158),
#  ('comments', 1155),
#  ('general', 1149),
#  ('sequences', 1149),
#  ('lee', 1149),
#  ('points', 1146),
#  ('earlier', 1146),
#  ('gone', 1137),
#  ('check', 1137),
#  ('suspense', 1134),
#  ('recommended', 1134),
#  ('ten', 1134),
#  ('third', 1131),
#  ('business', 1131),
#  ('talk', 1125),
#  ('leaves', 1125),
#  ('beyond', 1125),
#  ('portrayal', 1122),
#  ('beautifully', 1119),
#  ('single', 1116),
#  ('bill', 1116),
#  ('plenty', 1113),
#  ('word', 1113),
#  ('whom', 1110),
#  ('falls', 1110),
#  ('scary', 1107),
#  ('non', 1107),
#  ('figure', 1107),
#  ('battle', 1107),
#  ('using', 1104),
#  ('return', 1104),
#  ('doubt', 1101),
#  ('add', 1101),
#  ('hear', 1098),
#  ('solid', 1098),
#  ('success', 1098),
#  ('jokes', 1095),
#  ('oh', 1095),
#  ('touching', 1095),
#  ('political', 1095),
#  ('hell', 1092),
#  ('awesome', 1092),
#  ('boys', 1092),
#  ('sexual', 1086),
#  ('recently', 1086),
#  ('dog', 1086),
#  ('please', 1083),
#  ('wouldn', 1083),
#  ('straight', 1083),
#  ('features', 1083),
#  ('forget', 1080),
#  ('setting', 1080),
#  ('lack', 1080),
#  ('married', 1077),
#  ('mark', 1077),
#  ('social', 1071),
#  ('interested', 1068),
#  ('adventure', 1068),
#  ('actual', 1065),
#  ('terrific', 1065),
#  ('sees', 1065),
#  ('brothers', 1065),
#  ('move', 1062),
#  ('call', 1062),
#  ('various', 1059),
#  ('theater', 1059),
#  ('dr', 1059),
#  ('animated', 1056),
#  ('western', 1053),
#  ('baby', 1050),
#  ('space', 1050),
#  ('leading', 1044),
#  ('disappointed', 1044),
#  ('portrayed', 1038),
#  ('aren', 1038),
#  ('screenplay', 1035),
#  ('smith', 1035),
#  ('towards', 1032),
#  ('hate', 1032),
#  ('noir', 1029),
#  ('outstanding', 1026),
#  ('decent', 1026),
#  ('kelly', 1026),
#  ('directors', 1023),
#  ('journey', 1023),
#  ('none', 1020),
#  ('looked', 1020),
#  ('effective', 1020),
#  ('storyline', 1017),
#  ('caught', 1017),
#  ('sci', 1017),
#  ('fi', 1017),
#  ('cold', 1017),
#  ('mary', 1017),
#  ('rich', 1014),
#  ('charming', 1014),
#  ('popular', 1011),
#  ('rare', 1011),
#  ('manages', 1011),
#  ('harry', 1011),
#  ('spirit', 1008),
#  ('appreciate', 1005),
#  ('open', 1005),
#  ('moves', 1002),
#  ('basically', 1002),
#  ('acted', 1002),
#  ('inside', 999),
#  ('boring', 999),
#  ('century', 999),
#  ('mention', 999),
#  ('deserves', 999),
#  ('subtle', 999),
#  ('pace', 999),
#  ('familiar', 996),
#  ('background', 996),
#  ('ben', 993),
#  ('creepy', 990),
#  ('supposed', 990),
#  ('secret', 987),
#  ('die', 984),
#  ('jim', 984),
#  ('question', 981),
#  ('effect', 981),
#  ('natural', 981),
#  ('impressive', 978),
#  ('rate', 978),
#  ('language', 978),
#  ('saying', 975),
#  ('intelligent', 975),
#  ('telling', 972),
#  ('realize', 972),
#  ('material', 972),
#  ('scott', 972),
#  ('singing', 969),
#  ('dancing', 966),
#  ('visual', 963),
#  ('adult', 963),
#  ('imagine', 963),
#  ('kept', 960),
#  ('office', 960),
#  ('uses', 957),
#  ('pure', 954),
#  ('wait', 954),
#  ('stunning', 954),
#  ('review', 951),
#  ('previous', 951),
#  ('copy', 951),
#  ('seriously', 951),
#  ('reading', 948),
#  ('create', 948),
#  ('hot', 948),
#  ('created', 948),
#  ('magic', 948),
#  ('somehow', 948),
#  ('stay', 945),
#  ('attempt', 945),
#  ('escape', 945),
#  ('crazy', 945),
#  ('air', 945),
#  ('frank', 945),
#  ('hands', 942),
#  ('filled', 939),
#  ('expected', 936),
#  ('average', 936),
#  ('surprisingly', 936),
#  ('complex', 933),
#  ('quickly', 930),
#  ('successful', 930),
#  ('studio', 930),
#  ('plus', 927),
#  ('male', 927),
#  ('co', 921),
#  ('images', 918),
#  ('casting', 918),
#  ('following', 918),
#  ('minute', 918),
#  ('exciting', 918),
#  ('members', 915),
#  ('follows', 915),
#  ('themes', 915),
#  ('german', 915),
#  ('reasons', 915),
#  ('e', 915),
#  ('touch', 912),
#  ('edge', 912),
#  ('free', 912),
#  ('cute', 912),
#  ('genius', 912),
#  ('outside', 909),
#  ('reviews', 906),
#  ('admit', 906),
#  ('ok', 906),
#  ('younger', 906),
#  ('fighting', 903),
#  ('odd', 903),
#  ('master', 903),
#  ('recent', 900),
#  ('thanks', 900),
#  ('break', 900),
#  ('comment', 900),
#  ('apart', 897),
#  ('emotions', 894),
#  ('lovely', 894),
#  ('begin', 894),
#  ('doctor', 891),
#  ('party', 891),
#  ('italian', 891),
#  ('la', 888),
#  ('missed', 888),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 1684386),
#  ('.', 502614),
#  ('the', 490167),
#  ('a', 237963),
#  ('and', 223155),
#  ('of', 207027),
#  ('to', 206922),
#  ('br', 157911),
#  ('is', 150249),
#  ('it', 144981),
#  ('i', 140640),
#  ('in', 131259),
#  ('this', 122760),
#  ('that', 112845),
#  ('s', 94638),
#  ('was', 78873),
#  ('movie', 74895),
#  ('for', 65781),
#  ('but', 65343),
#  ('with', 62634),
#  ('as', 61875),
#  ('t', 61083),
#  ('film', 57654),
#  ('you', 52647),
#  ('on', 51576),
#  ('not', 49062),
#  ('have', 45432),
#  ('are', 43869),
#  ('be', 43623),
#  ('he', 41568),
#  ('one', 39402),
#  ('they', 39033),
#  ('at', 36837),
#  ('his', 36441),
#  ('all', 36108),
#  ('so', 34389),
#  ('like', 33714),
#  ('there', 32325),
#  ('just', 31857),
#  ('by', 31647),
#  ('or', 30816),
#  ('an', 30798),
#  ('who', 29907),
#  ('from', 29193),
#  ('if', 28554),
#  ('about', 27183),
#  ('out', 26937),
#  ('what', 25266),
#  ('some', 24918),
#  ('no', 24429),
#  ('her', 23841),
#  ('even', 23061),
#  ('can', 22959),
#  ('has', 22812),
#  ('good', 22269),
#  ('bad', 22203),
#  ('would', 21108),
#  ('up', 20910),
#  ('only', 20343),
#  ('more', 20190),
#  ('when', 20178),
#  ('she', 19332),
#  ('really', 18786),
#  ('time', 18627),
#  ('had', 18426),
#  ('my', 18045),
#  ('were', 18003),
#  ('which', 17340),
#  ('very', 17292),
#  ('me', 16818),
#  ('see', 16356),
#  ('don', 16008),
#  ('we', 15984),
#  ('their', 15834),
#  ('do', 15708),
#  ('story', 15624),
#  ('than', 15549),
#  ('been', 15300),
#  ('much', 15234),
#  ('get', 15111),
#  ('because', 14898),
#  ('people', 14418),
#  ('then', 14283),
#  ('make', 14166),
#  ('how', 14064),
#  ('could', 14058),
#  ('any', 13974),
#  ('into', 13701),
#  ('made', 13623),
#  ('first', 12918),
#  ('other', 12915),
#  ('well', 12762),
#  ('too', 12522),
#  ('them', 12495),
#  ('plot', 12462),
#  ('movies', 12240),
#  ('acting', 12168),
#  ('will', 11979),
#  ('way', 11967),
#  ('most', 11757),
#  ('him', 11574),
#  ('after', 11514),
#  ('its', 10965),
#  ('think', 10929),
#  ('also', 10824),
#  ('characters', 10800),
#  ('off', 10701),
#  ('watch', 10650),
#  ('character', 10518),
#  ('did', 10518),
#  ('why', 10389),
#  ('being', 10179),
#  ('better', 10074),
#  ('know', 10002),
#  ('over', 9948),
#  ('seen', 9795),
#  ('ever', 9789),
#  ('never', 9777),
#  ('your', 9699),
#  ('where', 9657),
#  ('two', 9519),
#  ('little', 9288),
#  ('films', 9231),
#  ('here', 9081),
#  ('m', 9000),
#  ('nothing', 8970),
#  ('say', 8946),
#  ('end', 8862),
#  ('something', 8826),
#  ('should', 8760),
#  ('many', 8727),
#  ('does', 8613),
#  ('thing', 8598),
#  ('show', 8586),
#  ('ve', 8487),
#  ('scene', 8448),
#  ('scenes', 8355),
#  ('these', 8172),
#  ('go', 8151),
#  ('didn', 7938),
#  ('great', 7920),
#  ('watching', 7920),
#  ('re', 7860),
#  ('doesn', 7803),
#  ('through', 7680),
#  ('such', 7632),
#  ('man', 7548),
#  ('worst', 7440),
#  ('actually', 7347),
#  ('actors', 7311),
#  ('life', 7287),
#  ('back', 7272),
#  ('while', 7254),
#  ('director', 7215),
#  ('funny', 7008),
#  ('going', 6957),
#  ('still', 6849),
#  ('another', 6762),
#  ('look', 6741),
#  ('now', 6711),
#  ('old', 6645),
#  ('those', 6636),
#  ('real', 6510),
#  ('few', 6474),
#  ('love', 6456),
#  ('horror', 6450),
#  ('before', 6441),
#  ('want', 6423),
#  ('minutes', 6378),
#  ('pretty', 6345),
#  ('best', 6282),
#  ('though', 6273),
#  ('same', 6243),
#  ('script', 6222),
#  ('work', 6081),
#  ('every', 6075),
#  ('seems', 6069),
#  ('least', 6033),
#  ('enough', 5991),
#  ('down', 5964),
#  ('original', 5949),
#  ('guy', 5892),
#  ('got', 5856),
#  ('around', 5829),
#  ('part', 5826),
#  ('lot', 5676),
#  ('anything', 5622),
#  ('find', 5580),
#  ('new', 5562),
#  ('again', 5547),
#  ('isn', 5547),
#  ('point', 5535),
#  ('things', 5517),
#  ('fact', 5517),
#  ('give', 5469),
#  ('makes', 5442),
#  ('take', 5400),
#  ('thought', 5394),
#  ('d', 5310),
#  ('whole', 5304),
#  ('long', 5283),
#  ('years', 5277),
#  ('however', 5220),
#  ('gets', 5142),
#  ('making', 5085),
#  ('cast', 5082),
#  ('big', 4986),
#  ('might', 4974),
#  ('interesting', 4944),
#  ('money', 4914),
#  ('us', 4884),
#  ('right', 4875),
#  ('far', 4857),
#  ('quite', 4788),
#  ('without', 4785),
#  ('come', 4785),
#  ('almost', 4722),
#  ('ll', 4701),
#  ('action', 4698),
#  ('awful', 4671),
#  ('kind', 4617),
#  ('reason', 4602),
#  ('am', 4590),
#  ('looks', 4584),
#  ('must', 4566),
#  ('done', 4530),
#  ('comedy', 4512),
#  ('someone', 4470),
#  ('trying', 4458),
#  ('wasn', 4452),
#  ('poor', 4443),
#  ('boring', 4434),
#  ('instead', 4434),
#  ('saw', 4425),
#  ('away', 4407),
#  ('girl', 4389),
#  ('probably', 4332),
#  ('believe', 4302),
#  ('sure', 4299),
#  ('looking', 4290),
#  ('stupid', 4284),
#  ('anyone', 4254),
#  ('times', 4218),
#  ('maybe', 4212),
#  ('world', 4212),
#  ('rather', 4182),
#  ('terrible', 4173),
#  ('may', 4170),
#  ('last', 4170),
#  ('since', 4164),
#  ('let', 4155),
#  ('tv', 4146),
#  ('hard', 4122),
#  ('between', 4122),
#  ('waste', 4074),
#  ('woman', 4068),
#  ('feel', 4062),
#  ('effects', 4044),
#  ('half', 4023),
#  ('own', 3999),
#  ('young', 3951),
#  ('music', 3948),
#  ('idea', 3936),
#  ('sense', 3918),
#  ('bit', 3894),
#  ('having', 3840),
#  ('book', 3834),
#  ('found', 3801),
#  ('put', 3789),
#  ('series', 3789),
#  ('goes', 3768),
#  ('worse', 3747),
#  ('said', 3690),
#  ('comes', 3672),
#  ('role', 3666),
#  ('main', 3660),
#  ('else', 3597),
#  ('everything', 3591),
#  ('yet', 3588),
#  ('low', 3567),
#  ('screen', 3564),
#  ('supposed', 3558),
#  ('actor', 3555),
#  ('either', 3549),
#  ('budget', 3537),
#  ('ending', 3537),
#  ('audience', 3534),
#  ('set', 3531),
#  ('family', 3510),
#  ('left', 3507),
#  ('completely', 3504),
#  ('both', 3474),
#  ('wrong', 3465),
#  ('always', 3453),
#  ('course', 3444),
#  ('place', 3444),
#  ('seem', 3441),
#  ('watched', 3426),
#  ('day', 3396),
#  ('simply', 3390),
#  ('shot', 3378),
#  ('mean', 3351),
#  ('special', 3306),
#  ('dead', 3303),
#  ('three', 3282),
#  ('house', 3255),
#  ('oh', 3252),
#  ('night', 3249),
#  ('read', 3246),
#  ('less', 3201),
#  ('high', 3198),
#  ('year', 3192),
#  ('camera', 3183),
#  ('worth', 3171),
#  ('our', 3168),
#  ('try', 3153),
#  ('horrible', 3138),
#  ('sex', 3138),
#  ('video', 3129),
#  ('black', 3117),
#  ('although', 3108),
#  ('couldn', 3108),
#  ('once', 3099),
#  ('rest', 3066),
#  ('dvd', 3063),
#  ('line', 3054),
#  ('played', 3051),
#  ('fun', 3021),
#  ('during', 3018),
#  ('production', 3009),
#  ('everyone', 3006),
#  ('play', 2979),
#  ('mind', 2970),
#  ('version', 2967),
#  ('kids', 2967),
#  ('seeing', 2964),
#  ('american', 2940),
#  ('given', 2934),
#  ('used', 2907),
#  ('performance', 2904),
#  ('especially', 2889),
#  ('together', 2889),
#  ('tell', 2877),
#  ('women', 2874),
#  ('start', 2868),
#  ('need', 2865),
#  ('second', 2859),
#  ('takes', 2850),
#  ('each', 2850),
#  ('wife', 2832),
#  ('dialogue', 2826),
#  ('use', 2820),
#  ('problem', 2814),
#  ('star', 2802),
#  ('unfortunately', 2793),
#  ('himself', 2787),
#  ('doing', 2778),
#  ('death', 2766),
#  ('name', 2763),
#  ('lines', 2757),
#  ('killer', 2742),
#  ('getting', 2739),
#  ('help', 2715),
#  ('couple', 2706),
#  ('fan', 2706),
#  ('head', 2694),
#  ('crap', 2685),
#  ('guess', 2664),
#  ('piece', 2652),
#  ('nice', 2640),
#  ('different', 2634),
#  ('school', 2628),
#  ('later', 2625),
#  ('entire', 2607),
#  ('shows', 2580),
#  ('next', 2574),
#  ('john', 2574),
#  ('short', 2571),
#  ('seemed', 2571),
#  ('hollywood', 2550),
#  ('home', 2544),
#  ('true', 2538),
#  ('person', 2538),
#  ('absolutely', 2526),
#  ('sort', 2520),
#  ('care', 2517),
#  ('understand', 2508),
#  ('plays', 2505),
#  ('felt', 2502),
#  ('written', 2487),
#  ('title', 2484),
#  ('men', 2466),
#  ('until', 2463),
#  ('flick', 2448),
#  ('decent', 2445),
#  ('face', 2442),
#  ('friends', 2430),
#  ('stars', 2421),
#  ('job', 2421),
#  ('case', 2421),
#  ('itself', 2412),
#  ('yes', 2403),
#  ('perhaps', 2400),
#  ('went', 2391),
#  ('wanted', 2391),
#  ('called', 2388),
#  ('annoying', 2385),
#  ('ridiculous', 2370),
#  ('tries', 2370),
#  ('laugh', 2364),
#  ('evil', 2361),
#  ('along', 2358),
#  ('top', 2355),
#  ('hour', 2352),
#  ('full', 2349),
#  ('came', 2340),
#  ('writing', 2340),
#  ('keep', 2310),
#  ('totally', 2301),
#  ('playing', 2298),
#  ('god', 2295),
#  ('won', 2292),
#  ('guys', 2289),
#  ('already', 2286),
#  ('gore', 2271),
#  ('direction', 2244),
#  ('save', 2238),
#  ('lost', 2235),
#  ('example', 2232),
#  ('sound', 2226),
#  ('war', 2223),
#  ('attempt', 2205),
#  ('car', 2199),
#  ('except', 2199),
#  ('moments', 2196),
#  ('blood', 2196),
#  ('obviously', 2190),
#  ('act', 2187),
#  ('remember', 2184),
#  ('kill', 2181),
#  ('truly', 2178),
#  ('white', 2178),
#  ('father', 2178),
#  ('b', 2175),
#  ('thinking', 2160),
#  ('ok', 2148),
#  ('finally', 2148),
#  ('turn', 2133),
#  ('quality', 2103),
#  ('lack', 2094),
#  ('style', 2082),
#  ('wouldn', 2079),
#  ('cheap', 2073),
#  ('none', 2070),
#  ('kid', 2058),
#  ('please', 2058),
#  ('boy', 2055),
#  ('seriously', 2052),
#  ('lead', 2040),
#  ('dull', 2031),
#  ('children', 2028),
#  ('starts', 2025),
#  ('stuff', 2019),
#  ('hope', 2016),
#  ('looked', 2010),
#  ('recommend', 2007),
#  ('under', 2004),
#  ('run', 2001),
#  ('killed', 2001),
#  ('enjoy', 1998),
#  ('others', 1998),
#  ('etc', 1989),
#  ('myself', 1989),
#  ('beginning', 1986),
#  ('girls', 1986),
#  ('against', 1986),
#  ('obvious', 1980),
#  ('small', 1980),
#  ('hell', 1977),
#  ('slow', 1971),
#  ('hand', 1968),
#  ('wonder', 1956),
#  ('lame', 1956),
#  ('becomes', 1953),
#  ('picture', 1953),
#  ('based', 1950),
#  ('early', 1944),
#  ('behind', 1938),
#  ('poorly', 1932),
#  ('avoid', 1926),
#  ('apparently', 1920),
#  ('complete', 1920),
#  ('happens', 1917),
#  ('anyway', 1914),
#  ('classic', 1911),
#  ('several', 1908),
#  ('despite', 1905),
#  ('certainly', 1905),
#  ('episode', 1905),
#  ('often', 1893),
#  ('cut', 1890),
#  ('writer', 1890),
#  ('mother', 1884),
#  ('predictable', 1884),
#  ('gave', 1884),
#  ('become', 1881),
#  ('close', 1875),
#  ('fans', 1872),
#  ('saying', 1863),
#  ('scary', 1857),
#  ('stop', 1854),
#  ('live', 1854),
#  ('wants', 1851),
#  ('self', 1845),
#  ('mr', 1836),
#  ('jokes', 1833),
#  ('friend', 1833),
#  ('cannot', 1830),
#  ('overall', 1827),
#  ('cinema', 1812),
#  ('child', 1809),
#  ('silly', 1803),
#  ('beautiful', 1788),
#  ('human', 1785),
#  ('expect', 1782),
#  ('liked', 1779),
#  ('happened', 1776),
#  ('bunch', 1770),
#  ('entertaining', 1770),
#  ('actress', 1764),
#  ('final', 1764),
#  ('says', 1752),
#  ('performances', 1752),
#  ('turns', 1731),
#  ('humor', 1731),
#  ('themselves', 1728),
#  ('eyes', 1728),
#  ('hours', 1722),
#  ('happen', 1719),
#  ('basically', 1716),
#  ('days', 1716),
#  ('running', 1713),
#  ('involved', 1707),
#  ('disappointed', 1707),
#  ('call', 1707),
#  ('directed', 1704),
#  ('group', 1704),
#  ('fight', 1701),
#  ('daughter', 1698),
#  ('talking', 1698),
#  ('body', 1698),
#  ('badly', 1695),
#  ('sorry', 1695),
#  ('throughout', 1689),
#  ('viewer', 1689),
#  ('yourself', 1686),
#  ('extremely', 1686),
#  ('interest', 1683),
#  ('heard', 1683),
#  ('violence', 1683),
#  ('shots', 1677),
#  ('side', 1671),
#  ('word', 1668),
#  ('art', 1665),
#  ('possible', 1662),
#  ('dark', 1653),
#  ('game', 1653),
#  ('hero', 1650),
#  ('alone', 1647),
#  ('son', 1641),
#  ('type', 1641),
#  ('leave', 1641),
#  ('gives', 1638),
#  ('parts', 1638),
#  ('single', 1638),
#  ('started', 1635),
#  ('female', 1629),
#  ('rating', 1623),
#  ('mess', 1623),
#  ('voice', 1623),
#  ('aren', 1620),
#  ('town', 1620),
#  ('drama', 1614),
#  ('definitely', 1611),
#  ('unless', 1608),
#  ('review', 1602),
#  ('effort', 1599),
#  ('weak', 1599),
#  ('able', 1599),
#  ('took', 1593),
#  ('non', 1590),
#  ('five', 1590),
#  ('matter', 1587),
#  ('usually', 1587),
#  ('michael', 1584),
#  ('feeling', 1578),
#  ('huge', 1569),
#  ('sequel', 1566),
#  ('soon', 1563),
#  ('exactly', 1560),
#  ('past', 1557),
#  ('turned', 1554),
#  ('police', 1554),
#  ('tried', 1545),
#  ('middle', 1539),
#  ('talent', 1539),
#  ('genre', 1536),
#  ('zombie', 1530),
#  ('ends', 1527),
#  ('history', 1527),
#  ('straight', 1509),
#  ('opening', 1503),
#  ('serious', 1503),
#  ('coming', 1503),
#  ('moment', 1500),
#  ('lives', 1497),
#  ('sad', 1497),
#  ('dialog', 1494),
#  ('particularly', 1494),
#  ('editing', 1479),
#  ('clearly', 1476),
#  ('beyond', 1473),
#  ('earth', 1473),
#  ('taken', 1470),
#  ('cool', 1470),
#  ('level', 1467),
#  ('dumb', 1467),
#  ('okay', 1464),
#  ('major', 1461),
#  ('fast', 1455),
#  ('premise', 1455),
#  ('joke', 1452),
#  ('stories', 1452),
#  ('wasted', 1449),
#  ('minute', 1449),
#  ('across', 1446),
#  ('mostly', 1446),
#  ('rent', 1446),
#  ('late', 1443),
#  ('falls', 1443),
#  ('fails', 1443),
#  ('mention', 1434),
#  ('theater', 1425),
#  ('stay', 1416),
#  ('sometimes', 1416),
#  ('hit', 1404),
#  ('talk', 1401),
#  ('fine', 1401),
#  ('die', 1398),
#  ('storyline', 1395),
#  ('pointless', 1395),
#  ('taking', 1392),
#  ('order', 1386),
#  ('brother', 1383),
#  ('whatever', 1380),
#  ('told', 1380),
#  ('wish', 1374),
#  ('room', 1368),
#  ('career', 1365),
#  ('appears', 1365),
#  ('write', 1365),
#  ('known', 1362),
#  ('husband', 1362),
#  ('living', 1353),
#  ('sit', 1350),
#  ('ten', 1350),
#  ('words', 1347),
#  ('monster', 1344),
#  ('chance', 1344),
#  ('hate', 1332),
#  ('novel', 1332),
#  ('add', 1329),
#  ('english', 1329),
#  ('somehow', 1323),
#  ('strange', 1320),
#  ('imdb', 1314),
#  ('actual', 1314),
#  ('total', 1311),
#  ('material', 1311),
#  ('killing', 1311),
#  ('ones', 1311),
#  ('knew', 1308),
#  ('king', 1302),
#  ('number', 1302),
#  ('using', 1299),
#  ('lee', 1293),
#  ('power', 1293),
#  ('shown', 1293),
#  ('works', 1293),
#  ('giving', 1293),
#  ('points', 1290),
#  ('possibly', 1290),
#  ('kept', 1290),
#  ('four', 1287),
#  ('local', 1281),
#  ('usual', 1278),
#  ('including', 1275),
#  ('problems', 1272),
#  ('ago', 1272),
#  ('opinion', 1272),
#  ('nudity', 1269),
#  ('age', 1266),
#  ('due', 1263),
#  ('roles', 1260),
#  ('writers', 1257),
#  ('decided', 1257),
#  ('near', 1254),
#  ('flat', 1254),
#  ('easily', 1254),
#  ('murder', 1251),
#  ('experience', 1251),
#  ('reviews', 1248),
#  ('imagine', 1245),
#  ('feels', 1239),
#  ('plain', 1233),
#  ('somewhat', 1233),
#  ('class', 1230),
#  ('score', 1230),
#  ('song', 1227),
#  ('bring', 1227),
#  ('whether', 1227),
#  ('otherwise', 1224),
#  ('whose', 1224),
#  ('average', 1224),
#  ('pathetic', 1221),
#  ('nearly', 1221),
#  ('knows', 1221),
#  ('zombies', 1221),
#  ('cinematography', 1218),
#  ('cheesy', 1218),
#  ('upon', 1218),
#  ('city', 1215),
#  ('space', 1215),
#  ('credits', 1212),
#  ('james', 1209),
#  ('lots', 1209),
#  ('change', 1209),
#  ('entertainment', 1206),
#  ('nor', 1206),
#  ('wait', 1203),
#  ('released', 1200),
#  ('needs', 1197),
#  ('shame', 1194),
#  ('attention', 1188),
#  ('comments', 1182),
#  ('bored', 1179),
#  ('free', 1179),
#  ('lady', 1179),
#  ('expected', 1176),
#  ('needed', 1176),
#  ('clear', 1176),
#  ('view', 1173),
#  ('development', 1170),
#  ('check', 1170),
#  ('doubt', 1170),
#  ('figure', 1167),
#  ('mystery', 1167),
#  ('excellent', 1164),
#  ('garbage', 1164),
#  ('sequence', 1158),
#  ('television', 1158),
#  ('o', 1155),
#  ('sets', 1155),
#  ('laughable', 1152),
#  ('potential', 1152),
#  ('robert', 1146),
#  ('light', 1146),
#  ('country', 1146),
#  ('documentary', 1146),
#  ('reality', 1146),
#  ('general', 1143),
#  ('ask', 1143),
#  ('comic', 1140),
#  ('fall', 1140),
#  ('begin', 1140),
#  ('footage', 1137),
#  ('stand', 1137),
#  ('forced', 1137),
#  ('trash', 1137),
#  ('remake', 1137),
#  ('thriller', 1134),
#  ('songs', 1134),
#  ('gay', 1131),
#  ('within', 1131),
#  ('hardly', 1128),
#  ('above', 1125),
#  ('gone', 1125),
#  ('george', 1122),
#  ('means', 1119),
#  ('sounds', 1119),
#  ('directing', 1116),
#  ('move', 1116),
#  ('david', 1116),
#  ('buy', 1116),
#  ('rock', 1113),
#  ('forward', 1113),
#  ('important', 1113),
#  ('hot', 1110),
#  ('haven', 1110),
#  ('filmed', 1110),
#  ('british', 1110),
#  ('heart', 1107),
#  ('reading', 1107),
#  ('fake', 1107),
#  ('incredibly', 1104),
#  ('weird', 1104),
#  ('hear', 1104),
#  ('enjoyed', 1101),
#  ('hilarious', 1101),
#  ('cop', 1101),
#  ('musical', 1101),
#  ('message', 1098),
#  ('happy', 1098),
#  ('pay', 1098),
#  ('laughs', 1095),
#  ('box', 1095),
#  ('suspense', 1089),
#  ('sadly', 1089),
#  ('eye', 1086),
#  ('third', 1083),
#  ('similar', 1083),
#  ('named', 1083),
#  ('modern', 1080),
#  ('failed', 1077),
#  ('events', 1077),
#  ('forget', 1074),
#  ('question', 1074),
#  ('male', 1071),
#  ('finds', 1071),
#  ('perfect', 1068),
#  ('spent', 1065),
#  ('sister', 1065),
#  ('feature', 1062),
#  ('result', 1062),
#  ('comment', 1059),
#  ('girlfriend', 1059),
#  ('sexual', 1056),
#  ('attempts', 1053),
#  ('neither', 1053),
#  ('richard', 1053),
#  ('screenplay', 1050),
#  ('elements', 1050),
#  ('spoilers', 1047),
#  ('brain', 1044),
#  ('filmmakers', 1044),
#  ('showing', 1044),
#  ('miss', 1041),
#  ('dr', 1041),
#  ('christmas', 1041),
#  ('cover', 1035),
#  ('red', 1032),
#  ('sequences', 1032),
#  ('typical', 1029),
#  ('excuse', 1029),
#  ('crazy', 1026),
#  ('ideas', 1026),
#  ('baby', 1026),
#  ('loved', 1023),
#  ('meant', 1023),
#  ('worked', 1020),
#  ('fire', 1020),
#  ('unbelievable', 1017),
#  ('follow', 1017),
#  ('theme', 1011),
#  ('barely', 1008),
#  ('producers', 1008),
#  ('twist', 1008),
#  ('plus', 1008),
#  ('appear', 1008),
#  ('directors', 1005),
#  ('team', 1005),
#  ('viewers', 999),
#  ('leads', 996),
#  ('tom', 996),
#  ('slasher', 996),
#  ('wrote', 993),
#  ('villain', 993),
#  ('gun', 993),
#  ('working', 993),
#  ('island', 990),
#  ('strong', 990),
#  ('open', 990),
#  ('realize', 990),
#  ('positive', 987),
#  ('disappointing', 987),
#  ('yeah', 987),
#  ('quickly', 987),
#  ('weren', 984),
#  ('release', 984),
#  ('simple', 984),
#  ('honestly', 984),
#  ('eventually', 981),
#  ('period', 981),
#  ('tells', 981),
#  ('kills', 981),
#  ('doctor', 981),
#  ('nowhere', 978),
#  ('list', 978),
#  ('acted', 978),
#  ('herself', 978),
#  ('dog', 978),
#  ('walk', 975),
#  ('air', 972),
#  ('apart', 972),
#  ('makers', 969),
#  ('subject', 969),
#  ('learn', 966),
#  ('fi', 966),
#  ('sci', 957),
#  ('bother', 957),
#  ('admit', 957),
#  ('jack', 954),
#  ('disappointment', 954),
#  ('hands', 954),
#  ('note', 954),
#  ('certain', 951),
#  ('e', 951),
#  ('value', 951),
#  ('casting', 951),
#  ('grade', 948),
#  ('peter', 948),
#  ('suddenly', 945),
#  ('missing', 945),
#  ('form', 939),
#  ('stick', 939),
#  ('previous', 939),
#  ('break', 939),
#  ('soundtrack', 936),
#  ('surprised', 933),
#  ('front', 933),
#  ('expecting', 933),
#  ('parents', 930),
#  ('surprise', 930),
#  ('relationship', 930),
#  ('shoot', 927),
#  ('today', 927),
#  ('painful', 924),
#  ('ways', 924),
#  ('leaves', 924),
#  ('ended', 924),
#  ('creepy', 924),
#  ('concept', 924),
#  ('somewhere', 924),
#  ('vampire', 924),
#  ('spend', 921),
#  ('th', 921),
#  ('future', 918),
#  ('difficult', 918),
#  ('effect', 918),
#  ('fighting', 918),
#  ('street', 918),
#  ('c', 915),
#  ('america', 915),
#  ('accent', 912),
#  ('truth', 906),
#  ('project', 906),
#  ('joe', 903),
#  ('f', 903),
#  ('deal', 903),
#  ('indeed', 903),
#  ('biggest', 900),
#  ('rate', 900),
#  ('paul', 897),
#  ('japanese', 897),
#  ('utterly', 894),
#  ('begins', 894),
#  ('redeeming', 894),
#  ('college', 894),
#  ('york', 891),
#  ('fairly', 891),
#  ('disney', 891),
#  ('crew', 888),
#  ('create', 888),
#  ('cartoon', 888),
#  ('revenge', 888),
#  ('co', 885),
#  ('outside', 885),
#  ('computer', 885),
#  ('interested', 885),
#  ('stage', 885),
#  ('considering', 882),
#  ('speak', 882),
#  ('among', 882),
#  ('towards', 879),
#  ('channel', 879),
#  ('sick', 879),
#  ('talented', 876),
#  ('cause', 876),
#  ('particular', 876),
#  ('van', 876),
#  ('hair', 876),
#  ('bottom', 873),
#  ('reasons', 873),
#  ('mediocre', 870),
#  ('cat', 870),
#  ('telling', 870),
#  ('supporting', 867),
#  ('store', 867),
#  ('hoping', 864),
#  ('waiting', 864),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and 
# negative uses of the most common words
#       Consider words to be "common" if they've 
# been used at least 100 times

for term,cnt in list(total_counts.most_common()):
    if(cnt > 100):
        pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
        pos_neg_ratios[term] = pos_neg_ratio

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0608036428326615
# Pos-to-neg ratio for 'amazing' = 4.033036848792884
# Pos-to-neg ratio for 'terrible' = 0.17752755150934355

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs
for word,ratio in pos_neg_ratios.most_common():
    pos_neg_ratios[word] = np.log(ratio)

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05902677448642055
# Pos-to-neg ratio for 'amazing' = 1.3945196526689512
# Pos-to-neg ratio for 'terrible' = -1.7286294623410592

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 5.7899601708972535),
#  ('paulie', 4.483002552013883),
#  ('felix', 3.295836866004329),
#  ('polanski', 2.941144083269588),
#  ('matthau', 2.883682769745368),
#  ('victoria', 2.726483902791048),
#  ('mildred', 2.6897010624340134),
#  ('gandhi', 2.615934912194404),
#  ('flawless', 2.5199979695992702),
#  ('superbly', 2.317183892415198),
#  ('perfection', 2.20494662343013),
#  ('astaire', 2.188856327665703),
#  ('voight', 2.082814226158475),
#  ('captures', 2.0656482195475),
#  ('wonderfully', 2.0395956331326364),
#  ('powell', 2.0043209112117277),
#  ('brosnan', 1.9973587108913553),
#  ('lily', 1.9603821816638478),
#  ('bakshi', 1.9429904389519785),
#  ('lincoln', 1.9308722716907727),
#  ('lemmon', 1.8912890645750882),
#  ('refreshing', 1.8792788472446116),
#  ('breathtaking', 1.87752629098548),
#  ('bourne', 1.8738244222823592),
#  ('flynn', 1.8319255109533896),
#  ('delightful', 1.8175119653304697),
#  ('homer', 1.8147489874527538),
#  ('andrews', 1.8072636557640203),
#  ('soccer', 1.803320291629131),
#  ('beautifully', 1.773166636151439),
#  ('elvira', 1.7691169924782952),
#  ('gripping', 1.7459499331967607),
#  ('underrated', 1.7384781026151184),
#  ('superb', 1.7156449752072436),
#  ('sadness', 1.7012454616872232),
#  ('delight', 1.6985019757414723),
#  ('welles', 1.6845139388744574),
#  ('timeless', 1.6631420914059614),
#  ('macy', 1.6611392868109909),
#  ('sinatra', 1.6558038329920262),
#  ('hartley', 1.6494432470477995),
#  ('touching', 1.6466515087745348),
#  ('unforgettable', 1.6459075922154918),
#  ('favorites', 1.6376087894007967),
#  ('extraordinary', 1.6326947745983675),
#  ('sullivan', 1.6304913216319328),
#  ('stewart', 1.6205824769871655),
#  ('brilliantly', 1.611049516328442),
#  ('palma', 1.5910887737659039),
#  ('friendship', 1.5814640603916943),
#  ('ritter', 1.5686159179138452),
#  ('wonderful', 1.566868174969685),
#  ('magnificent', 1.5612358106162227),
#  ('jackie', 1.5603171150991502),
#  ('finest', 1.5599578551707307),
#  ('tremendous', 1.547880019434667),
#  ('freedom', 1.5243826629370196),
#  ('pleasantly', 1.5188924825614147),
#  ('mann', 1.5188924825614147),
#  ('sidney', 1.5143338969434632),
#  ('terrific', 1.5111445639993666),
#  ('fantastic', 1.509451689942051),
#  ('nancy', 1.5040773967762742),
#  ('noir', 1.50262073227981),
#  ('outstanding', 1.499701022176475),
#  ('marie', 1.4968571488027869),
#  ('marvelous', 1.4964727973910548),
#  ('ruth', 1.4890395194117334),
#  ('excellent', 1.4664691168591149),
#  ('stanwyck', 1.4629501053524112),
#  ('widmark', 1.4575573811413813),
#  ('splendid', 1.455287232606842),
#  ('tender', 1.4448885253859434),
#  ('exceptional', 1.4434527749598391),
#  ('chan', 1.4399154525589883),
#  ('gentle', 1.4372144515471477),
#  ('poignant', 1.4240346891027378),
#  ('captivating', 1.4144652380865868),
#  ('fisher', 1.4122698475231514),
#  ('davies', 1.4122698475231514),
#  ('chilling', 1.4060969884160703),
#  ('gem', 1.402517196626778),
#  ('amazing', 1.3945196526689512),
#  ('darker', 1.3934118288887545),
#  ('april', 1.3821875791672373),
#  ('blake', 1.37125648375535),
#  ('overlooked', 1.3541372494853594),
#  ('kelly', 1.3536931997444925),
#  ('ralph', 1.349926716949016),
#  ('cole', 1.3362839405452291),
#  ('bette', 1.3360856655371443),
#  ('hoffman', 1.331873970147904),
#  ('shines', 1.3260021308637706),
#  ('winters', 1.3127602770737414),
#  ('notch', 1.3106710075578265),
#  ('powerful', 1.3049914138340664),
#  ('vivid', 1.3044643428722584),
#  ('pitt', 1.3022112439093492),
#  ('giallo', 1.3004784415350346),
#  ('remarkable', 1.2983689072841658),
#  ('psychiatrist', 1.2935126276689244),
#  ('portrait', 1.2915159547926012),
#  ('gritty', 1.2913778046231477),
#  ('innocence', 1.2892326482767593),
#  ('garbo', 1.2883688239495823),
#  ('ensemble', 1.286075244962483),
#  ('holly', 1.2809338454620642),
#  ('panic', 1.2787384548986287),
#  ('burns', 1.2766875545806133),
#  ('philip', 1.2714551015075206),
#  ('barbara', 1.270462545594769),
#  ('carol', 1.2698840092754793),
#  ('stunning', 1.26967669093743),
#  ('favorite', 1.2693586852184033),
#  ('rural', 1.2625001437732262),
#  ('appreciated', 1.2615157596049626),
#  ('brooklyn', 1.2568362938830038),
#  ('builds', 1.2565153181139184),
#  ('favourite', 1.2501621867953105),
#  ('perfect', 1.2486116401364886),
#  ('unfolds', 1.2445662012911896),
#  ('journey', 1.2435194096118067),
#  ('von', 1.2411753533229801),
#  ('bond', 1.2408393882601862),
#  ('brilliant', 1.2312184691988761),
#  ('recommended', 1.222365491310997),
#  ('daniel', 1.2143482407027684),
#  ('crafted', 1.2134925646665318),
#  ('troubled', 1.2119409739751128),
#  ('consequences', 1.209837923778334),
#  ('prince', 1.2034919194885851),
#  ('perfectly', 1.2017077976950838),
#  ('alexander', 1.1992558144477972),
#  ('boxing', 1.195986452693286),
#  ('haunting', 1.1939224684724346),
#  ('cinderella', 1.1922478937021024),
#  ('expressions', 0.5917946862996578),
#  ('struggles', 0.5917946862996578),
#  ('timing', 0.5914631396314276),
#  ('growing', 0.5909165579110467),
#  ('clint', 0.5906075412437604),
#  ('helen', 0.5898295665319193),
#  ('authentic', 0.5896575728379307),
#  ('quirky', 0.5860025431086177),
#  ('touch', 0.5851585424958494),
#  ('timothy', 0.5851585424958494),
#  ('streep', 0.5848060367639812),
#  ('mexico', 0.5844309570551467),
#  ('personalities', 0.5838340905862957),
#  ('inner', 0.5833520678342533),
#  ('pre', 0.58287265009969),
#  ('lives', 0.582431899764459),
#  ('sisters', 0.5817896454297448),
#  ('overcome', 0.5817443504461564),
#  ('civil', 0.5811421221834504),
#  ('australia', 0.5804065576044966),
#  ('tales', 0.5802678324880917),
#  ('surprises', 0.5801820655168997),
#  ('adventures', 0.5801820655168997),
#  ('countries', 0.5795730663647302),
#  ('realism', 0.578887829759989),
#  ('tradition', 0.5782172138859684),
#  ('wealth', 0.5764229062518039),
#  ('overwhelming', 0.5764229062518039),
#  ('odds', 0.5764229062518039),
#  ('young', 0.5758226683081469),
#  ('oliver', 0.5751015053748032),
#  ('rogers', 0.5750244132882678),
#  ('french', 0.5744111704517905),
#  ('performing', 0.5736020299101626),
#  ('suspenseful', 0.5732585643392092),
#  ('variety', 0.5732585643392092),
#  ('survival', 0.5731878654809663),
#  ('understanding', 0.5720027972008571),
#  ('players', 0.5715261440303387),
#  ('reminiscent', 0.5700870878027181),
#  ('branagh', 0.5694680843784343),
#  ('war', 0.5693320494928339),
#  ('knowing', 0.5690165622201285),
#  ('kirk', 0.568790164211464),
#  ('jr', 0.5682888691888515),
#  ('psychological', 0.5679840376059393),
#  ('grand', 0.5655859549219265),
#  ('howard', 0.5651531793814153),
#  ('mainstream', 0.5647971466774202),
#  ('grow', 0.564288693634815),
#  ('sent', 0.564256167491925),
#  ('generation', 0.564070138284803),
#  ('true', 0.5636026534235863),
#  ('brothers', 0.5622012870840272),
#  ('disc', 0.5618111784988583),
#  ('bug', 0.5618111784988583),
#  ('dick', 0.5605027059536506),
#  ('gangster', 0.5591108649254527),
#  ('tend', 0.5590077003520756),
#  ('sutherland', 0.5587991280288668),
#  ('david', 0.5587201318074783),
#  ('tribute', 0.5586692663313919),
#  ('sacrifice', 0.5585875102098568),
#  ('jeff', 0.5578721083305959),
#  ('charm', 0.5573660682014072),
#  ('twists', 0.5566226698672908),
#  ('hearts', 0.5557473111575023),
#  ('greek', 0.5549968420791281),
#  ('hamilton', 0.5549968420791281),
#  ('describes', 0.5545006872686523),
#  ('thanks', 0.5543518888158816),
#  ('europe', 0.5535953001538397),
#  ('redemption', 0.5532259898366517),
#  ('pulls', 0.552518526064661),
#  ('documentaries', 0.5520685823000399),
#  ('jealous', 0.5520685823000399),
#  ('family', 0.55173192119805),
#  ('madness', 0.5515577266056603),
#  ('mountains', 0.5513169851207276),
#  ('trial', 0.5509726917794027),
#  ('brilliance', 0.549504478331102),
#  ('superior', 0.549148872196705),
#  ('color', 0.5485659517488377),
#  ('providing', 0.5485659517488377),
#  ('spirit', 0.4779717988949124),
#  ('losing', 0.47787768567664146),
#  ('dated', 0.4777100149814932),
#  ('smaller', 0.4772090129670057),
#  ('crisis', 0.47712109701459954),
#  ('challenge', 0.4765610297918946),
#  ('soviet', 0.4764168440804488),
#  ('episode', 0.4763449704055887),
#  ('inevitable', 0.4757816065256241),
#  ('role', 0.4757479389858427),
#  ('familiar', 0.4756419849000022),
#  ('genuinely', 0.47561071747492417),
#  ('ways', 0.47539447788061195),
#  ('francisco', 0.4735185713531801),
#  ('techniques', 0.4731832821631153),
#  ('surfing', 0.4710623905939776),
#  ('spielberg', 0.4707056299765654),
#  ('cynical', 0.4707056299765654),
#  ('tour', 0.4707056299765654),
#  ('higher', 0.4692548459834945),
#  ('ryan', 0.46903791212577656),
#  ('dream', 0.4686972933316801),
#  ('critics', 0.468644009729696),
#  ('born', 0.46859814763700064),
#  ('defeat', 0.46798546508949834),
#  ('african', 0.4678827376765979),
#  ('detective', 0.467415696969703),
#  ('warner', 0.4669501917588453),
#  ('remains', 0.4665528000880026),
#  ('deserved', 0.465915164156503),
#  ('lynch', 0.46572429962636125),
#  ('information', 0.46548311783441726),
#  ('struggle', 0.46438099164475904),
#  ('breaking', 0.4634523657585138),
#  ('shadows', 0.46262352194811296),
#  ('language', 0.46226270650129747),
#  ('hidden', 0.46178353869838795),
#  ('visual', 0.46152462073862727),
#  ('social', 0.4601549944047847),
#  ('treasure', 0.45930834012898764),
#  ('closely', 0.45920938411485507),
#  ('segments', 0.45920938411485507),
#  ('reality', 0.45893562956958045),
#  ('presents', 0.4580024416360459),
#  ('mixed', 0.4579552907295611),
#  ('hamlet', 0.4573499434771761),
#  ('popular', 0.45722704266675385),
#  ('sometimes', 0.4570406491811901),
#  ('modern', 0.45685090515523236),
#  ('web', 0.4567584024957149),
#  ('chief', 0.4563851985354213),
#  ('represents', 0.45610884092691933),
#  ('follows', 0.45589596173505637),
#  ('surprised', 0.4555799782337876),
#  ('justice', 0.4555256100650824),
#  ('oz', 0.4550620492475365),
#  ('keeps', 0.45501892256289367),
#  ('caine', 0.4546553522989361),
#  ('restaurant', 0.4545977966858091),
#  ('john', 0.4528673470027483),
#  ('rap', 0.4526118865338664),
#  ('birth', 0.452382027895916),
#  ('welcome', 0.45234869400701483),
#  ('lose', 0.45153386019749325),
#  ('searching', 0.4509274821849217),
#  ('chinese', 0.45013754815975693),
#  ('closer', 0.4500972621289327),
#  ('jon', 0.44991687067899816),
#  ('years', 0.44957082995808745),
#  ('controversial', 0.44942823152928046),
#  ('fame', 0.44926773076655735),
#  ('caught', 0.44917967934446995),
#  ('wallace', 0.4486372799733731),
#  ('visuals', 0.448589534741919),
#  ('elizabeth', 0.4484311439916077),
#  ('thrilling', 0.44802472252696035),
#  ('bridge', 0.44802472252696035),
#  ('puts', 0.44727537816817936),
#  ('criminal', 0.4464965047860269),
#  ('marry', 0.4461361478390922),
#  ('ocean', 0.44595646946290124),
#  ('enormous', 0.44595646946290124),
#  ('revolutionary', 0.44595646946290124),
#  ('minor', 0.4451777455150322),
#  ('nazi', 0.4450307083143556),
#  ('learned', 0.44494391908195186),
#  ('flaws', 0.44450565731176456),
#  ('wayne', 0.4444080820567718),
#  ('michelle', 0.44430494142442833),
#  ('cary', 0.4440799442359439),
#  ('comedic', 0.44260465505762114),
#  ('de', 0.44216647495859235),
#  ('slowly', 0.4419803210832619),
#  ('liked', 0.441872879884831),
#  ('physical', 0.4408429471898154),
#  ('glenn', 0.4408044745534733),
#  ('light', 0.4405864909013839),
#  ('johnny', 0.44027451277402563),
#  ('international', 0.44000543336034054),
#  ('married', 0.4394627166495841),
#  ('sandler', 0.4390414036417687),
#  ('pride', 0.4386173154250649),
#  ('vision', 0.4384351273457342),
#  ('beings', 0.438041278542777),
#  ('comedies', 0.4378180725599301),
#  ('silent', 0.4378180725599301),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('boll', -4.965172920019499),
#  ('uwe', -4.618415412738112),
#  ('seagal', -3.6397767411062043),
#  ('unwatchable', -3.2516656476911914),
#  ('stinker', -3.2020687065518194),
#  ('mst', -2.946386399450836),
#  ('incoherent', -2.931828471574511),
#  ('unfunny', -2.689580019039809),
#  ('waste', -2.6188938868722635),
#  ('blah', -2.5667791841386127),
#  ('horrid', -2.478714679540079),
#  ('pointless', -2.453874540540272),
#  ('atrocious', -2.4222182679385904),
#  ('redeeming', -2.3660069194315416),
#  ('prom', -2.354544831924757),
#  ('drivel', -2.3412228856994597),
#  ('lousy', -2.304250372313107),
#  ('worst', -2.2867191512177283),
#  ('laughable', -2.262630777487013),
#  ('awful', -2.2267662564366946),
#  ('poorly', -2.2197209484908624),
#  ('wasting', -2.199690669831413),
#  ('remotely', -2.193318322369154),
#  ('existent', -2.0748011621233338),
#  ('boredom', -1.9897527869194898),
#  ('miserably', -1.9863511186138239),
#  ('sucks', -1.9843764298831092),
#  ('lame', -1.9807460083977015),
#  ('uninspired', -1.9771626925594177),
#  ('insult', -1.9747930232040993)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = set(total_counts.keys())

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1,vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'responsive': 1,
#  'shumachers': 2,
#  'murphy': 3,
#  'madwoman': 4,
#  'muro': 5,
#  'mercifully': 6,
#  'federally': 7,
#  'oiks': 8,
#  'tony': 9,
#  'enfants': 10,
#  'hrabosky': 11,
#  'spinner': 12,
#  'rajendra': 13,
#  'franker': 14,
#  'portman': 15,
#  'middle': 16,
#  'fintail': 17,
#  'lacy': 18,
#  'investments': 19,
#  'gertrude': 20,
#  'washi': 21,
#  'taft': 22,
#  'prefers': 23,
#  'abott': 24,
#  'bores': 25,
#  'michiko': 26,
#  'burl': 27,
#  'guillaumme': 28,
#  'sucka': 29,
#  'rouncewell': 30,
#  'infidelity': 31,
#  'amic': 32,
#  'linkin': 33,
#  'subscribed': 34,
#  'gotuntil': 35,
#  'ignorant': 36,
#  'advisers': 37,
#  'shutterbug': 38,
#  'intoned': 39,
#  'unspeakably': 40,
#  'quadrophenia': 41,
#  'inem': 42,
#  'fending': 43,
#  'exempted': 44,
#  'tins': 45,
#  'umptieth': 46,
#  'sequals': 47,
#  'redub': 48,
#  'lindsay': 49,
#  'vaster': 50,
#  'stellas': 51,
#  'mathis': 52,
#  'acquainted': 53,
#  'deel': 54,
#  'cel': 55,
#  'mentalities': 56,
#  'facilty': 57,
#  'soma': 58,
#  'ands': 59,
#  'managing': 60,
#  'flaunt': 61,
#  'zschering': 62,
#  'calista': 63,
#  'simpson': 64,
#  'fancifully': 65,
#  'cooperate': 66,
#  'prete': 67,
#  'enquanto': 68,
#  'dioz': 69,
#  'merideth': 70,
#  'usmc': 71,
#  'tomie': 72,
#  'rhythmically': 73,
#  'munter': 74,
#  'parrots': 75,
#  'invaluable': 76,
#  'hellbound': 77,
#  'feder': 78,
#  'advances': 79,
#  'downwards': 80,
#  'gnome': 81,
#  'decency': 82,
#  'atlante': 83,
#  'pussycats': 84,
#  'redeemable': 85,
#  'moss': 86,
#  'plunkett': 87,
#  'crushingly': 88,
#  'roy': 89,
#  'forums': 90,
#  'pelicangs': 91,
#  'legion': 92,
#  'constanly': 93,
#  'bestiality': 94,
#  'sedgwick': 95,
#  'iberia': 96,
#  'diffusional': 97,
#  'hoarse': 98,
#  'loudly': 99,
#  'burchill': 100,
#  'unredeemably': 101,
#  'chummies': 102,
#  'age': 103,
#  'hourglass': 104,
#  'fora': 105,
#  'diatribes': 106,
#  'sourly': 107,
#  'benji': 108,
#  'poisoning': 109,
#  'rested': 110,
#  'patrician': 111,
#  'gatsby': 112,
#  'modernist': 113,
#  'snazzy': 114,
#  'criticzed': 115,
#  'bottle': 116,
#  'floozy': 117,
#  'psmith': 118,
#  'sawpart': 119,
#  'haves': 120,
#  'tastes': 121,
#  'schne': 122,
#  'meoli': 123,
#  'krystina': 124,
#  'mcgrath': 125,
#  'defrost': 126,
#  'watkins': 127,
#  'scares': 128,
#  'inhibited': 129,
#  'luise': 130,
#  'awwwww': 131,
#  'ealing': 132,
#  'ahlstedt': 133,
#  'ices': 134,
#  'sebastians': 135,
#  'name': 136,
#  'nam': 137,
#  'arklie': 138,
#  'caring': 139,
#  'tristran': 140,
#  'menczer': 141,
#  'matched': 142,
#  'westfront': 143,
#  'chu': 144,
#  'bonesetter': 145,
#  'menotti': 146,
#  'chruch': 147,
#  'schwartzman': 148,
#  'founding': 149,
#  'overplaying': 150,
#  'starpower': 151,
#  'sporadically': 152,
#  'megabomb': 153,
#  'giddily': 154,
#  'rauol': 155,
#  'obtrudes': 156,
#  'nabbing': 157,
#  'psychomania': 158,
#  'almira': 159,
#  'airport': 160,
#  'antenna': 161,
#  'tussles': 162,
#  'chapters': 163,
#  'scoff': 164,
#  'patni': 165,
#  'commandents': 166,
#  'youuuu': 167,
#  'menen': 168,
#  'boggins': 169,
#  'hush': 170,
#  'affords': 171,
#  'love': 172,
#  'hodgkins': 173,
#  'endure': 174,
#  'size': 175,
#  'lommel': 176,
#  'slugs': 177,
#  'primarilly': 178,
#  'asterix': 179,
#  'gains': 180,
#  'curled': 181,
#  'unceremonious': 182,
#  'wars': 183,
#  'spurring': 184,
#  'oscillators': 185,
#  'unbounded': 186,
#  'quarrels': 187,
#  'irby': 188,
#  'anguish': 189,
#  'befriend': 190,
#  'fricker': 191,
#  'coalition': 192,
#  'tensionless': 193,
#  'countess': 194,
#  'tastin': 195,
#  'clouded': 196,
#  'satanically': 197,
#  'pilfers': 198,
#  'matt': 199,
#  'vanquish': 200,
#  'documnetary': 201,
#  'unconstructive': 202,
#  'carfax': 203,
#  'isis': 204,
#  'worthy': 205,
#  'realizes': 206,
#  'altercation': 207,
#  'rogue': 208,
#  'rolle': 209,
#  'pised': 210,
#  'discouragement': 211,
#  'conjure': 212,
#  'binding': 213,
#  'drowning': 214,
#  'halifax': 215,
#  'surmising': 216,
#  'poisoner': 217,
#  'goodness': 218,
#  'qur': 219,
#  'valentinov': 220,
#  'guard': 221,
#  'rev': 222,
#  'kabaree': 223,
#  'bipartisanism': 224,
#  'jillson': 225,
#  'turnpoint': 226,
#  'rohan': 227,
#  'teddy': 228,
#  'lassander': 229,
#  'philomath': 230,
#  'hata': 231,
#  'eikenberry': 232,
#  'watermelons': 233,
#  'columbusland': 234,
#  'edelman': 235,
#  'bowers': 236,
#  'curious': 237,
#  'housemates': 238,
#  'thy': 239,
#  'detect': 240,
#  'outsmart': 241,
#  'gnawed': 242,
#  'abhisheh': 243,
#  'damiano': 244,
#  'marijuana': 245,
#  'humility': 246,
#  'sporty': 247,
#  'lindstrm': 248,
#  'gata': 249,
#  'pickpocket': 250,
#  'experts': 251,
#  'temperatures': 252,
#  'saloshin': 253,
#  'fortinbras': 254,
#  'presently': 255,
#  'iphigenia': 256,
#  'dozing': 257,
#  'submit': 258,
#  'fiennes': 259,
#  'spate': 260,
#  'discredit': 261,
#  'overacts': 262,
#  'janset': 263,
#  'blackish': 264,
#  'touchy': 265,
#  'undoubtedly': 266,
#  'plausibility': 267,
#  'factors': 268,
#  'ropier': 269,
#  'bloomberg': 270,
#  'disown': 271,
#  'moped': 272,
#  'wonka': 273,
#  'listeners': 274,
#  'pickpockets': 275,
#  'jerilderie': 276,
#  'eyesore': 277,
#  'objectification': 278,
#  'destructing': 279,
#  'consign': 280,
#  'comprehensions': 281,
#  'bennet': 282,
#  'elmer': 283,
#  'bliss': 284,
#  'shriners': 285,
#  'probably': 286,
#  'avigdor': 287,
#  'booklets': 288,
#  'deutschland': 289,
#  'spaceflight': 290,
#  'footing': 291,
#  'tennyson': 292,
#  'bolster': 293,
#  'bllsosopher': 294,
#  'cole': 295,
#  'sinister': 296,
#  'strategized': 297,
#  'everyway': 298,
#  'sexploits': 299,
#  'gawking': 300,
#  'dellacqua': 301,
#  'anwar': 302,
#  'carthage': 303,
#  'policing': 304,
#  'understated': 305,
#  'gautam': 306,
#  'gets': 307,
#  'authur': 308,
#  'centralized': 309,
#  'dun': 310,
#  'hamper': 311,
#  'laurentiis': 312,
#  'portobello': 313,
#  'unfortuanitly': 314,
#  'shemekia': 315,
#  'duplication': 316,
#  'inflicted': 317,
#  'double': 318,
#  'cricket': 319,
#  'seaton': 320,
#  'untidy': 321,
#  'squandered': 322,
#  'solomon': 323,
#  'souly': 324,
#  'saigon': 325,
#  'titular': 326,
#  'handwriting': 327,
#  'olaris': 328,
#  'copiously': 329,
#  'francophiles': 330,
#  'prosthetic': 331,
#  'disembowel': 332,
#  'sharmila': 333,
#  'earley': 334,
#  'endingin': 335,
#  'sends': 336,
#  'spicing': 337,
#  'ashura': 338,
#  'bryan': 339,
#  'resourceful': 340,
#  'watch': 341,
#  'markets': 342,
#  'accumulating': 343,
#  'mustaches': 344,
#  'browder': 345,
#  'testicles': 346,
#  'combine': 347,
#  'enigma': 348,
#  'sun': 349,
#  'crown': 350,
#  'egotistical': 351,
#  'arranges': 352,
#  'stomach': 353,
#  'henna': 354,
#  'chai': 355,
#  'bsm': 356,
#  'plan': 357,
#  'borneo': 358,
#  'yah': 359,
#  'sluttishly': 360,
#  'suggested': 361,
#  'offends': 362,
#  'unbelievable': 363,
#  'rou': 364,
#  'fillmore': 365,
#  'payoffs': 366,
#  'stooped': 367,
#  'silliest': 368,
#  'peripheral': 369,
#  'filmfour': 370,
#  'shemp': 371,
#  'quantrell': 372,
#  'emeric': 373,
#  'quo': 374,
#  'conscript': 375,
#  'debilitating': 376,
#  'squirlyem': 377,
#  'adder': 378,
#  'contractors': 379,
#  'needs': 380,
#  'ros': 381,
#  'bandaur': 382,
#  'svankmajer': 383,
#  'atrocious': 384,
#  'cheese': 385,
#  'tacked': 386,
#  'mappo': 387,
#  'composited': 388,
#  'magnum': 389,
#  'collaborated': 390,
#  'biplane': 391,
#  'bonanzas': 392,
#  'slouchy': 393,
#  'exeption': 394,
#  'forebears': 395,
#  'espescially': 396,
#  'limitlessly': 397,
#  'ahhhhh': 398,
#  'porthos': 399,
#  'glamed': 400,
#  'nom': 401,
#  'synanomess': 402,
#  'embarrassments': 403,
#  'shivaji': 404,
#  'intimated': 405,
#  'gillian': 406,
#  'shortcomings': 407,
#  'sorted': 408,
#  'darkangel': 409,
#  'tuba': 410,
#  'feldman': 411,
#  'lachlin': 412,
#  'foaming': 413,
#  'stonewalled': 414,
#  'demolishes': 415,
#  'sturm': 416,
#  'nirvana': 417,
#  'tinseltown': 418,
#  'sabers': 419,
#  'microfiche': 420,
#  'needless': 421,
#  'rosalyin': 422,
#  'gramps': 423,
#  'brecht': 424,
#  'psychotics': 425,
#  'conditioning': 426,
#  'herbal': 427,
#  'relief': 428,
#  'pared': 429,
#  'cadet': 430,
#  'gaurentee': 431,
#  'pukey': 432,
#  'shoot': 433,
#  'chronicled': 434,
#  'punky': 435,
#  'berling': 436,
#  'sincere': 437,
#  'profited': 438,
#  'edendale': 439,
#  'jeayes': 440,
#  'brassieres': 441,
#  'emulsion': 442,
#  'aishwarya': 443,
#  'limned': 444,
#  'cute': 445,
#  'aggressiveness': 446,
#  'alarmist': 447,
#  'zeitgeist': 448,
#  'squawk': 449,
#  'offisde': 450,
#  'gogu': 451,
#  'debaser': 452,
#  'cuckold': 453,
#  'palooka': 454,
#  'entailed': 455,
#  'alright': 456,
#  'pocketbooks': 457,
#  'herds': 458,
#  'fantasizes': 459,
#  'hamnett': 460,
#  'spookhouse': 461,
#  'gracie': 462,
#  'crusades': 463,
#  'temuco': 464,
#  'nefarious': 465,
#  'deaths': 466,
#  'aloof': 467,
#  'flickers': 468,
#  'doughton': 469,
#  'werching': 470,
#  'negligible': 471,
#  'hutchison': 472,
#  'hime': 473,
#  'djimon': 474,
#  'recurve': 475,
#  'slagged': 476,
#  'illuminates': 477,
#  'tagalog': 478,
#  'waterloo': 479,
#  'hosing': 480,
#  'maharishi': 481,
#  'stratten': 482,
#  'liebmann': 483,
#  'confessing': 484,
#  'sieben': 485,
#  'unashamedly': 486,
#  'exerting': 487,
#  'mockery': 488,
#  'mourir': 489,
#  'misportrayed': 490,
#  'nikhilji': 491,
#  'jivetalking': 492,
#  'juan': 493,
#  'kaurismki': 494,
#  'allegations': 495,
#  'loder': 496,
#  'macallum': 497,
#  'moremuch': 498,
#  'showtunes': 499,
#  'tse': 500,
#  'approaching': 501,
#  'emigration': 502,
#  'achilles': 503,
#  'indifference': 504,
#  'conquests': 505,
#  'bernson': 506,
#  'perrault': 507,
#  'battery': 508,
#  'stylised': 509,
#  'gunned': 510,
#  'humpdorama': 511,
#  'persuasiveness': 512,
#  'monstro': 513,
#  'ofstars': 514,
#  'darr': 515,
#  'parter': 516,
#  'israle': 517,
#  'daddies': 518,
#  'yawnfest': 519,
#  'somnambulant': 520,
#  'camera': 521,
#  'dotted': 522,
#  'pyro': 523,
#  'ibnez': 524,
#  'peyote': 525,
#  'adj': 526,
#  'cavalry': 527,
#  'grandparents': 528,
#  'molded': 529,
#  'ashwar': 530,
#  'sedahl': 531,
#  'lots': 532,
#  'tired': 533,
#  'injection': 534,
#  'blat': 535,
#  'fuji': 536,
#  'screwup': 537,
#  'whored': 538,
#  'ethnocentric': 539,
#  'crandall': 540,
#  'resourcefully': 541,
#  'mdma': 542,
#  'wwwf': 543,
#  'especial': 544,
#  'berliner': 545,
#  'dabbled': 546,
#  'hammerstein': 547,
#  'marra': 548,
#  'trashes': 549,
#  'supply': 550,
#  'jalouse': 551,
#  'sgc': 552,
#  'mvp': 553,
#  'galvin': 554,
#  'fielder': 555,
#  'thinks': 556,
#  'distorts': 557,
#  'trowel': 558,
#  'unchoreographed': 559,
#  'lamest': 560,
#  'lemmings': 561,
#  'lemoraa': 562,
#  'ondu': 563,
#  'michaelangelo': 564,
#  'crockzilla': 565,
#  'aunties': 566,
#  'overplayed': 567,
#  'dupe': 568,
#  'salacious': 569,
#  'pity': 570,
#  'ruginis': 571,
#  'restrictions': 572,
#  'kyonki': 573,
#  'rockwood': 574,
#  'sena': 575,
#  'valencia': 576,
#  'risked': 577,
#  'stalks': 578,
#  'mist': 579,
#  'ignominious': 580,
#  'indignant': 581,
#  'mania': 582,
#  'awestruck': 583,
#  'authoritarian': 584,
#  'fridays': 585,
#  'denotes': 586,
#  'sargoth': 587,
#  'rosebud': 588,
#  'deepening': 589,
#  'miasma': 590,
#  'eventhough': 591,
#  'overtime': 592,
#  'pits': 593,
#  'biangle': 594,
#  'stepmother': 595,
#  'speilburg': 596,
#  'sits': 597,
#  'promote': 598,
#  'paleontologist': 599,
#  'groundbreaking': 600,
#  'laugthers': 601,
#  'utterings': 602,
#  'gillman': 603,
#  'specky': 604,
#  'correspondent': 605,
#  'duddley': 606,
#  'condors': 607,
#  'additionally': 608,
#  'dissapointment': 609,
#  'whod': 610,
#  'pointing': 611,
#  'presupposes': 612,
#  'soppy': 613,
#  'confrontational': 614,
#  'freddie': 615,
#  'seibert': 616,
#  'daivari': 617,
#  'reawakens': 618,
#  'prinz': 619,
#  'vastness': 620,
#  'blanket': 621,
#  'ferrel': 622,
#  'preempted': 623,
#  'eldon': 624,
#  'specimens': 625,
#  'yb': 626,
#  'slowing': 627,
#  'channels': 628,
#  'hood': 629,
#  'izo': 630,
#  'barish': 631,
#  'thunderball': 632,
#  'mowing': 633,
#  'murdoch': 634,
#  'excoriates': 635,
#  'gambits': 636,
#  'exited': 637,
#  'anyway': 638,
#  'wizs': 639,
#  'hereespecially': 640,
#  'radicalize': 641,
#  'ignorantly': 642,
#  'cheekboned': 643,
#  'convention': 644,
#  'cuddly': 645,
#  'rochon': 646,
#  'bleached': 647,
#  'hurls': 648,
#  'coleen': 649,
#  'letting': 650,
#  'hegemony': 651,
#  'catalogued': 652,
#  'factory': 653,
#  'abby': 654,
#  'occupant': 655,
#  'gluey': 656,
#  'ailing': 657,
#  'avengers': 658,
#  'ninnies': 659,
#  'reciprocation': 660,
#  'sarducci': 661,
#  'upturn': 662,
#  'beadle': 663,
#  'fascinatingly': 664,
#  'worhol': 665,
#  'flightplan': 666,
#  'bunged': 667,
#  'resses': 668,
#  'storia': 669,
#  'needful': 670,
#  'lf': 671,
#  'branson': 672,
#  'cum': 673,
#  'villalobos': 674,
#  'leashes': 675,
#  'jacob': 676,
#  'propagandistically': 677,
#  'nonfunctioning': 678,
#  'arithmetic': 679,
#  'thatwasjunk': 680,
#  'announce': 681,
#  'latrina': 682,
#  'coordinate': 683,
#  'yrigoyens': 684,
#  'individuation': 685,
#  'cayetana': 686,
#  'kardis': 687,
#  'roundtable': 688,
#  'lipgloss': 689,
#  'silencers': 690,
#  'tiness': 691,
#  'unctuous': 692,
#  'unsteerable': 693,
#  'hemlich': 694,
#  'mortgages': 695,
#  'involvement': 696,
#  'accusations': 697,
#  'coarse': 698,
#  'cease': 699,
#  'imprint': 700,
#  'dreamcatchers': 701,
#  'wizardry': 702,
#  'corrine': 703,
#  'daymio': 704,
#  'steepest': 705,
#  'khosla': 706,
#  'balinese': 707,
#  'vivre': 708,
#  'rainbow': 709,
#  'button': 710,
#  'wiseman': 711,
#  'lips': 712,
#  'stroud': 713,
#  'uncomically': 714,
#  'tuner': 715,
#  'godawful': 716,
#  'johnnie': 717,
#  'bostwick': 718,
#  'kaka': 719,
#  'dissent': 720,
#  'humped': 721,
#  'corean': 722,
#  'arggh': 723,
#  'sofcore': 724,
#  'snobby': 725,
#  'xxth': 726,
#  'blarney': 727,
#  'danayel': 728,
#  'bum': 729,
#  'reglamentary': 730,
#  'anticipation': 731,
#  'slipstream': 732,
#  'dependances': 733,
#  'ryker': 734,
#  'enjoy': 735,
#  'americans': 736,
#  'profuse': 737,
#  'minces': 738,
#  'vandervoort': 739,
#  'stomps': 740,
#  'washrooms': 741,
#  'angelos': 742,
#  'restricts': 743,
#  'cot': 744,
#  'classics': 745,
#  'construction': 746,
#  'leafs': 747,
#  'philosophise': 748,
#  'fibreglass': 749,
#  'interferring': 750,
#  'deviant': 751,
#  'saboteurs': 752,
#  'melba': 753,
#  'sossamon': 754,
#  'bergin': 755,
#  'babban': 756,
#  'malevolent': 757,
#  'eerieness': 758,
#  'tantrums': 759,
#  'doon': 760,
#  'hellebarde': 761,
#  'skirmish': 762,
#  'nether': 763,
#  'comin': 764,
#  'doorstop': 765,
#  'katryn': 766,
#  'muddily': 767,
#  'heaton': 768,
#  'cecelia': 769,
#  'mourby': 770,
#  'nickelby': 771,
#  'goins': 772,
#  'ethereally': 773,
#  'filipinos': 774,
#  'miyoshi': 775,
#  'razorfriendly': 776,
#  'apostoles': 777,
#  'gotb': 778,
#  'disarray': 779,
#  'gymnastix': 780,
#  'wobbled': 781,
#  'irreversible': 782,
#  'refrigerated': 783,
#  'dissecting': 784,
#  'midterm': 785,
#  'shakher': 786,
#  'longships': 787,
#  'senators': 788,
#  'rollerboys': 789,
#  'prewar': 790,
#  'hartman': 791,
#  'desires': 792,
#  'laundered': 793,
#  'lights': 794,
#  'stoney': 795,
#  'apprenticeship': 796,
#  'sette': 797,
#  'blurring': 798,
#  'thuggery': 799,
#  'rigged': 800,
#  'comely': 801,
#  'sniggering': 802,
#  'lever': 803,
#  'judged': 804,
#  'sabotages': 805,
#  'yamasato': 806,
#  'dalal': 807,
#  'itinerary': 808,
#  'spacesuit': 809,
#  'loading': 810,
#  'stab': 811,
#  'markel': 812,
#  'eccelston': 813,
#  'dop': 814,
#  'marin': 815,
#  'fleisher': 816,
#  'collared': 817,
#  'tonkin': 818,
#  'francais': 819,
#  'ulaganaayakan': 820,
#  'latched': 821,
#  'taccone': 822,
#  'dodes': 823,
#  'stores': 824,
#  'niche': 825,
#  'masauki': 826,
#  'haters': 827,
#  'amounting': 828,
#  'runmanian': 829,
#  'chauffeur': 830,
#  'saucepan': 831,
#  'tpb': 832,
#  'phh': 833,
#  'scourge': 834,
#  'devi': 835,
#  'prc': 836,
#  'charterers': 837,
#  'kraakman': 838,
#  'stark': 839,
#  'respiration': 840,
#  'blase': 841,
#  'busying': 842,
#  'sisterly': 843,
#  'teapot': 844,
#  'unhelpful': 845,
#  'waaaaaaaaay': 846,
#  'zhuangzhuang': 847,
#  'ganay': 848,
#  'cocks': 849,
#  'shek': 850,
#  'angeli': 851,
#  'huffs': 852,
#  'avoidable': 853,
#  'painkiller': 854,
#  'combust': 855,
#  'compliments': 856,
#  'byner': 857,
#  'ek': 858,
#  'eyesight': 859,
#  'holster': 860,
#  'hypothesized': 861,
#  'maddening': 862,
#  'punishing': 863,
#  'gissing': 864,
#  'intertwining': 865,
#  'seda': 866,
#  'dotes': 867,
#  'habituation': 868,
#  'stillman': 869,
#  'dedicative': 870,
#  'agreeable': 871,
#  'mcclug': 872,
#  'sourced': 873,
#  'ribcage': 874,
#  'quagmire': 875,
#  'garde': 876,
#  'libertini': 877,
#  'disband': 878,
#  'foretaste': 879,
#  'monson': 880,
#  'enbom': 881,
#  'pinko': 882,
#  'alas': 883,
#  'gleamed': 884,
#  'burgendy': 885,
#  'laterally': 886,
#  'acted': 887,
#  'athey': 888,
#  'oscillate': 889,
#  'reedus': 890,
#  'derivative': 891,
#  'brainwashed': 892,
#  'dorday': 893,
#  'nelli': 894,
#  'aargh': 895,
#  'manmohan': 896,
#  'blackadder': 897,
#  'exacted': 898,
#  'kelsey': 899,
#  'iris': 900,
#  'unpleasantness': 901,
#  'disable': 902,
#  'wyler': 903,
#  'grafting': 904,
#  'pendanski': 905,
#  'escalates': 906,
#  'lorain': 907,
#  'evoked': 908,
#  'ts': 909,
#  'mieze': 910,
#  'leonov': 911,
#  'chipped': 912,
#  'pernicious': 913,
#  'pretenses': 914,
#  'gagne': 915,
#  'turnoff': 916,
#  'childen': 917,
#  'pollock': 918,
#  'triad': 919,
#  'serra': 920,
#  'supplier': 921,
#  'samu': 922,
#  'perier': 923,
#  'subsidize': 924,
#  'overreacting': 925,
#  'braga': 926,
#  'berfield': 927,
#  'humiliation': 928,
#  'incomparably': 929,
#  'sgt': 930,
#  'hammill': 931,
#  'undressing': 932,
#  'minimize': 933,
#  'horrific': 934,
#  'subhuman': 935,
#  'anywho': 936,
#  'bachchan': 937,
#  'magical': 938,
#  'moltisanti': 939,
#  'film': 940,
#  'password': 941,
#  'hollanderize': 942,
#  'bataan': 943,
#  'caging': 944,
#  'selma': 945,
#  'colorous': 946,
#  'lumley': 947,
#  'brutishness': 948,
#  'haa': 949,
#  'cassandra': 950,
#  'headquarters': 951,
#  'hedonic': 952,
#  'kodokoo': 953,
#  'decadent': 954,
#  'nasal': 955,
#  'costumers': 956,
#  'deprave': 957,
#  'ava': 958,
#  'impressiveness': 959,
#  'sting': 960,
#  'sevillanas': 961,
#  'emsworth': 962,
#  'exemplifies': 963,
#  'nolan': 964,
#  'namaste': 965,
#  'tower': 966,
#  'piazza': 967,
#  'flabby': 968,
#  'jeepers': 969,
#  'assayas': 970,
#  'sollace': 971,
#  'alert': 972,
#  'rebuilding': 973,
#  'miscounted': 974,
#  'rohmer': 975,
#  'chupke': 976,
#  'storylife': 977,
#  'conquerer': 978,
#  'loooooove': 979,
#  'sega': 980,
#  'agents': 981,
#  'ward': 982,
#  'underpants': 983,
#  'associations': 984,
#  'damini': 985,
#  'respect': 986,
#  'busker': 987,
#  'roehler': 988,
#  'laurens': 989,
#  'jul': 990,
#  'rereads': 991,
#  'aaaahhhhhhh': 992,
#  'necroborg': 993,
#  'slush': 994,
#  'mada': 995,
#  'stomped': 996,
#  'ancestry': 997,
#  'notwithstanding': 998,
#  'furnace': 999,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    
    # count how many times each word is used in the given review and store the results in layer_0 
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[18.,  0.,  0., ...,  0.,  0.,  0.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    if(label == 'POSITIVE'):
        return 1
    else:
        return 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1234)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # The input layer, a two-dimensional matrix with shape 1 x input_nodes
        self.layer_0 = np.zeros((1,input_nodes))
    
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        
        for word in review.split(" "):
            # NOTE: This if-check was not in the version of this method created in Project 2,
            #       and it appears in Andrew's Project 3 solution without explanation. 
            #       It simply ensures the word is actually a key in word2index before
            #       accessing it, which is important because accessing an invalid key
            #       with raise an exception in Python. This allows us to ignore unknown
            #       words encountered in new reviews.
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:21.9% Speed(reviews/sec):984.2 #Correct:110 #Tested:220 Testing Accuracy:50.0%
# Progress:45.9% Speed(reviews/sec):1080. #Correct:230 #Tested:460 Testing Accuracy:50.0%
# Progress:66.5% Speed(reviews/sec):1060. #Correct:333 #Tested:666 Testing Accuracy:50.0%
# Progress:93.0% Speed(reviews/sec):1122. #Correct:466 #Tested:931 Testing Accuracy:50.0%
# Progress:99.9% Speed(reviews/sec):1143. #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):283.9 #Correct:1251 #Trained:2501 Training Accuracy:50.0%
# Progress:20.8% Speed(reviews/sec):283.0 #Correct:2501 #Trained:5001 Training Accuracy:50.0%
# Progress:31.2% Speed(reviews/sec):282.2 #Correct:3751 #Trained:7501 Training Accuracy:50.0%
# Progress:41.6% Speed(reviews/sec):279.7 #Correct:5001 #Trained:10001 Training Accuracy:50.0%
# Progress:52.0% Speed(reviews/sec):278.2 #Correct:6251 #Trained:12501 Training Accuracy:50.0%
# Progress:62.5% Speed(reviews/sec):276.1 #Correct:7501 #Trained:15001 Training Accuracy:50.0%
# Progress:72.9% Speed(reviews/sec):272.1 #Correct:8751 #Trained:17501 Training Accuracy:50.0%
# Progress:83.3% Speed(reviews/sec):258.9 #Correct:10001 #Trained:20001 Training Accuracy:50.0%
# Progress:93.7% Speed(reviews/sec):252.8 #Correct:11251 #Trained:22501 Training Accuracy:50.0%
# Progress:99.9% Speed(reviews/sec):249.8 #Correct:12000 #Trained:24000 Training Accuracy:50.0%

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):231.9 #Correct:1248 #Trained:2501 Training Accuracy:49.9%
# Progress:20.8% Speed(reviews/sec):225.1 #Correct:2498 #Trained:5001 Training Accuracy:49.9%
# Progress:31.2% Speed(reviews/sec):222.5 #Correct:3748 #Trained:7501 Training Accuracy:49.9%
# Progress:41.6% Speed(reviews/sec):222.7 #Correct:4998 #Trained:10001 Training Accuracy:49.9%
# Progress:52.0% Speed(reviews/sec):224.1 #Correct:6248 #Trained:12501 Training Accuracy:49.9%
# Progress:62.5% Speed(reviews/sec):226.4 #Correct:7493 #Trained:15001 Training Accuracy:49.9%
# Progress:72.9% Speed(reviews/sec):227.5 #Correct:8744 #Trained:17501 Training Accuracy:49.9%
# Progress:83.3% Speed(reviews/sec):228.6 #Correct:9994 #Trained:20001 Training Accuracy:49.9%
# Progress:93.7% Speed(reviews/sec):229.3 #Correct:11244 #Trained:22501 Training Accuracy:49.9%
# Progress:99.9% Speed(reviews/sec):229.6 #Correct:11993 #Trained:24000 Training Accuracy:49.9%

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# With a learning rate of `0.001`, the network should finally have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
